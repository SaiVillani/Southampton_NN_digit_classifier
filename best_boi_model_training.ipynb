# %%
# Cell 1: Imports and Setup
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import random
import os
from mnist_skeptic_v9 import skeptic_v9

# Set up GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Set random seed for reproducibility
random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)
# Out:
# Using device: cuda

# %%
# Cell 2: Data Loading and Transformation
transform = transforms.Compose([
    transforms.Resize((16, 16), interpolation=transforms.InterpolationMode.BICUBIC),
    transforms.RandomAffine(degrees=15, translate=(0.1, 0.1), scale=(0.9, 1.1), shear=15),
    transforms.ToTensor(),
    transforms.Lambda(lambda x: 1 - x if random.random() < 0.5 else x),
    transforms.Lambda(lambda x: x + 0.4 * torch.randn_like(x)),
    transforms.RandomErasing(p=0.5, scale=(0.02, 0.33), ratio=(0.3, 3.3), value=0),
    transforms.Normalize((0.1307,), (0.3081,))
])

# Load MNIST dataset
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, pin_memory=True)

# %%
# Cell 3: Training Function
# Cell 3: Training Function (Updated)
def train_model(model, train_loader, test_loader, epochs=20, patience=3, lr=0.001):
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2)
        
    best_accuracy = 0
    patience_counter = 0
    
    for epoch in range(epochs):
        model.train()
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            
        # Validation
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                outputs = model(data)
                _, predicted = torch.max(outputs.data, 1)
                total += target.size(0)
                correct += (predicted == target).sum().item()
        
        accuracy = 100 * correct / total
        print(f'Epoch {epoch+1}/{epochs}, Accuracy: {accuracy:.2f}%')
        
        scheduler.step(100 - accuracy)
        
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"Early stopping at epoch {epoch+1}")
                break
    
    return model, best_accuracy

# %%
# Cell 4: Ensemble Training (Updated)
def train_ensemble(num_models=20):
    ensemble = []
    for i in range(num_models):
        print(f"\nTraining model {i+1}/{num_models}")
        
        # Set a different random seed for each model
        seed = 42 + i
        torch.manual_seed(seed)
        if torch.cuda.is_available():
            torch.cuda.manual_seed_all(seed)
        
        model = skeptic_v9()
        
        # Slightly modify learning rate for each model
        lr = 0.001 * (1 + random.uniform(-0.1, 0.1))
        
        trained_model, accuracy = train_model(model, train_loader, test_loader, lr=lr)
        ensemble.append((trained_model, accuracy))
        print(f"Model {i+1} best accuracy: {accuracy:.2f}%")
    return ensemble

ensemble = train_ensemble(num_models=20)
# Out:
# Training model 1/20
# Epoch 1/20, Accuracy: 48.42%
# Epoch 2/20, Accuracy: 53.37%
# Epoch 3/20, Accuracy: 56.78%
# Epoch 4/20, Accuracy: 58.64%
# Epoch 5/20, Accuracy: 60.14%
# Epoch 6/20, Accuracy: 61.50%
# Epoch 7/20, Accuracy: 62.06%
# Epoch 8/20, Accuracy: 62.72%
# Epoch 9/20, Accuracy: 63.40%
# Epoch 10/20, Accuracy: 64.16%
# Epoch 11/20, Accuracy: 64.15%
# Epoch 12/20, Accuracy: 64.26%
# Epoch 13/20, Accuracy: 64.64%
# Epoch 14/20, Accuracy: 64.72%
# Epoch 15/20, Accuracy: 64.51%
# Epoch 16/20, Accuracy: 64.36%
# Epoch 17/20, Accuracy: 65.00%
# Epoch 18/20, Accuracy: 64.93%
# Epoch 19/20, Accuracy: 65.59%
# Epoch 20/20, Accuracy: 66.54%
# Model 1 best accuracy: 66.54%
#
# Training model 2/20
# Epoch 1/20, Accuracy: 43.96%
# Epoch 2/20, Accuracy: 50.46%
# Epoch 3/20, Accuracy: 52.70%
# Epoch 4/20, Accuracy: 55.57%
# Epoch 5/20, Accuracy: 58.72%
# Epoch 6/20, Accuracy: 60.06%
# Epoch 7/20, Accuracy: 60.18%
# Epoch 8/20, Accuracy: 62.01%
# Epoch 9/20, Accuracy: 62.93%
# Epoch 10/20, Accuracy: 62.87%
# Epoch 11/20, Accuracy: 64.29%
# Epoch 12/20, Accuracy: 62.96%
# Epoch 13/20, Accuracy: 64.84%
# Epoch 14/20, Accuracy: 64.68%
# Epoch 15/20, Accuracy: 65.73%
# Epoch 16/20, Accuracy: 65.55%
# Epoch 17/20, Accuracy: 65.47%
# Epoch 18/20, Accuracy: 66.34%
# Epoch 19/20, Accuracy: 66.28%
# Epoch 20/20, Accuracy: 65.98%
# Model 2 best accuracy: 66.34%
#
# Training model 3/20
# Epoch 1/20, Accuracy: 47.53%
# Epoch 2/20, Accuracy: 53.81%
# Epoch 3/20, Accuracy: 56.98%
# Epoch 4/20, Accuracy: 60.34%
# Epoch 5/20, Accuracy: 60.96%
# Epoch 6/20, Accuracy: 62.02%
# Epoch 7/20, Accuracy: 62.00%
# Epoch 8/20, Accuracy: 63.48%
# Epoch 9/20, Accuracy: 64.28%
# Epoch 10/20, Accuracy: 63.83%
# Epoch 11/20, Accuracy: 64.39%
# Epoch 12/20, Accuracy: 64.82%
# Epoch 13/20, Accuracy: 65.32%
# Epoch 14/20, Accuracy: 65.35%
# Epoch 15/20, Accuracy: 66.39%
# Epoch 16/20, Accuracy: 65.98%
# Epoch 17/20, Accuracy: 66.44%
# Epoch 18/20, Accuracy: 66.58%
# Epoch 19/20, Accuracy: 66.86%
# Epoch 20/20, Accuracy: 67.64%
# Model 3 best accuracy: 67.64%
#
# Training model 4/20
# Epoch 1/20, Accuracy: 47.63%
# Epoch 2/20, Accuracy: 52.77%
# Epoch 3/20, Accuracy: 56.20%
# Epoch 4/20, Accuracy: 58.09%
# Epoch 5/20, Accuracy: 58.57%
# Epoch 6/20, Accuracy: 60.59%
# Epoch 7/20, Accuracy: 60.89%
# Epoch 8/20, Accuracy: 61.65%
# Epoch 9/20, Accuracy: 62.36%
# Epoch 10/20, Accuracy: 63.59%
# Epoch 11/20, Accuracy: 63.82%
# Epoch 12/20, Accuracy: 64.77%
# Epoch 13/20, Accuracy: 65.19%
# Epoch 14/20, Accuracy: 66.18%
# Epoch 15/20, Accuracy: 65.85%
# Epoch 16/20, Accuracy: 65.08%
# Epoch 17/20, Accuracy: 65.97%
# Early stopping at epoch 17
# Model 4 best accuracy: 66.18%
#
# Training model 5/20
# Epoch 1/20, Accuracy: 50.02%
# Epoch 2/20, Accuracy: 54.86%
# Epoch 3/20, Accuracy: 56.83%
# Epoch 4/20, Accuracy: 59.99%
# Epoch 5/20, Accuracy: 60.50%
# Epoch 6/20, Accuracy: 61.45%
# Epoch 7/20, Accuracy: 61.73%
# Epoch 8/20, Accuracy: 63.37%
# Epoch 9/20, Accuracy: 63.07%
# Epoch 10/20, Accuracy: 62.88%
# Epoch 11/20, Accuracy: 63.59%
# Epoch 12/20, Accuracy: 64.12%
# Epoch 13/20, Accuracy: 64.31%
# Epoch 14/20, Accuracy: 63.94%
# Epoch 15/20, Accuracy: 64.59%
# Epoch 16/20, Accuracy: 66.35%
# Epoch 17/20, Accuracy: 66.19%
# Epoch 18/20, Accuracy: 66.19%
# Epoch 19/20, Accuracy: 66.18%
# Early stopping at epoch 19
# Model 5 best accuracy: 66.35%
#
# Training model 6/20
# Epoch 1/20, Accuracy: 50.06%
# Epoch 2/20, Accuracy: 55.96%
# Epoch 3/20, Accuracy: 58.73%
# Epoch 4/20, Accuracy: 60.11%
# Epoch 5/20, Accuracy: 61.60%
# Epoch 6/20, Accuracy: 61.55%
# Epoch 7/20, Accuracy: 63.05%
# Epoch 8/20, Accuracy: 63.89%
# Epoch 9/20, Accuracy: 64.36%
# Epoch 10/20, Accuracy: 64.79%
# Epoch 11/20, Accuracy: 64.57%
# Epoch 12/20, Accuracy: 65.78%
# Epoch 13/20, Accuracy: 66.54%
# Epoch 14/20, Accuracy: 67.00%
# Epoch 15/20, Accuracy: 66.51%
# Epoch 16/20, Accuracy: 66.57%
# Epoch 17/20, Accuracy: 67.36%
# Epoch 18/20, Accuracy: 67.05%
# Epoch 19/20, Accuracy: 66.95%
# Epoch 20/20, Accuracy: 66.64%
# Early stopping at epoch 20
# Model 6 best accuracy: 67.36%
#
# Training model 7/20
# Epoch 1/20, Accuracy: 49.68%
# Epoch 2/20, Accuracy: 54.46%
# Epoch 3/20, Accuracy: 56.88%
# Epoch 4/20, Accuracy: 58.77%
# Epoch 5/20, Accuracy: 61.49%
# Epoch 6/20, Accuracy: 62.15%
# Epoch 7/20, Accuracy: 61.35%
# Epoch 8/20, Accuracy: 63.57%
# Epoch 9/20, Accuracy: 62.81%
# Epoch 10/20, Accuracy: 64.23%
# Epoch 11/20, Accuracy: 65.32%
# Epoch 12/20, Accuracy: 64.91%
# Epoch 13/20, Accuracy: 65.12%
# Epoch 14/20, Accuracy: 65.98%
# Epoch 15/20, Accuracy: 65.63%
# Epoch 16/20, Accuracy: 67.06%
# Epoch 17/20, Accuracy: 65.90%
# Epoch 18/20, Accuracy: 67.18%
# Epoch 19/20, Accuracy: 68.04%
# Epoch 20/20, Accuracy: 66.57%
# Model 7 best accuracy: 68.04%
#
# Training model 8/20
# Epoch 1/20, Accuracy: 49.67%
# Epoch 2/20, Accuracy: 55.84%
# Epoch 3/20, Accuracy: 57.93%
# Epoch 4/20, Accuracy: 59.71%
# Epoch 5/20, Accuracy: 60.21%
# Epoch 6/20, Accuracy: 62.81%
# Epoch 7/20, Accuracy: 62.60%
# Epoch 8/20, Accuracy: 63.16%
# Epoch 9/20, Accuracy: 63.48%
# Epoch 10/20, Accuracy: 63.63%
# Epoch 11/20, Accuracy: 64.68%
# Epoch 12/20, Accuracy: 64.76%
# Epoch 13/20, Accuracy: 64.53%
# Epoch 14/20, Accuracy: 65.58%
# Epoch 15/20, Accuracy: 65.94%
# Epoch 16/20, Accuracy: 65.13%
# Epoch 17/20, Accuracy: 65.77%
# Epoch 18/20, Accuracy: 66.61%
# Epoch 19/20, Accuracy: 66.02%
# Epoch 20/20, Accuracy: 66.93%
# Model 8 best accuracy: 66.93%
#
# Training model 9/20
# Epoch 1/20, Accuracy: 51.77%
# Epoch 2/20, Accuracy: 54.84%
# Epoch 3/20, Accuracy: 59.13%
# Epoch 4/20, Accuracy: 59.83%
# Epoch 5/20, Accuracy: 60.40%
# Epoch 6/20, Accuracy: 62.02%
# Epoch 7/20, Accuracy: 62.50%
# Epoch 8/20, Accuracy: 63.09%
# Epoch 9/20, Accuracy: 64.49%
# Epoch 10/20, Accuracy: 65.12%
# Epoch 11/20, Accuracy: 64.89%
# Epoch 12/20, Accuracy: 65.63%
# Epoch 13/20, Accuracy: 65.81%
# Epoch 14/20, Accuracy: 66.09%
# Epoch 15/20, Accuracy: 65.96%
# Epoch 16/20, Accuracy: 66.30%
# Epoch 17/20, Accuracy: 66.45%
# Epoch 18/20, Accuracy: 67.41%
# Epoch 19/20, Accuracy: 67.54%
# Epoch 20/20, Accuracy: 67.17%
# Model 9 best accuracy: 67.54%
#
# Training model 10/20
# Epoch 1/20, Accuracy: 53.38%
# Epoch 2/20, Accuracy: 57.23%
# Epoch 3/20, Accuracy: 59.57%
# Epoch 4/20, Accuracy: 61.72%
# Epoch 5/20, Accuracy: 62.13%
# Epoch 6/20, Accuracy: 63.12%
# Epoch 7/20, Accuracy: 62.81%
# Epoch 8/20, Accuracy: 63.72%
# Epoch 9/20, Accuracy: 64.58%
# Epoch 10/20, Accuracy: 64.78%
# Epoch 11/20, Accuracy: 65.43%
# Epoch 12/20, Accuracy: 65.02%
# Epoch 13/20, Accuracy: 65.52%
# Epoch 14/20, Accuracy: 65.63%
# Epoch 15/20, Accuracy: 65.54%
# Epoch 16/20, Accuracy: 66.06%
# Epoch 17/20, Accuracy: 66.03%
# Epoch 18/20, Accuracy: 67.35%
# Epoch 19/20, Accuracy: 66.13%
# Epoch 20/20, Accuracy: 67.28%
# Model 10 best accuracy: 67.35%
#
# Training model 11/20
# Epoch 1/20, Accuracy: 49.22%
# Epoch 2/20, Accuracy: 54.11%
# Epoch 3/20, Accuracy: 57.74%
# Epoch 4/20, Accuracy: 58.71%
# Epoch 5/20, Accuracy: 60.40%
# Epoch 6/20, Accuracy: 61.68%
# Epoch 7/20, Accuracy: 62.25%
# Epoch 8/20, Accuracy: 63.89%
# Epoch 9/20, Accuracy: 63.57%
# Epoch 10/20, Accuracy: 62.60%
# Epoch 11/20, Accuracy: 63.92%
# Epoch 12/20, Accuracy: 65.19%
# Epoch 13/20, Accuracy: 65.33%
# Epoch 14/20, Accuracy: 65.52%
# Epoch 15/20, Accuracy: 65.95%
# Epoch 16/20, Accuracy: 65.74%
# Epoch 17/20, Accuracy: 66.35%
# Epoch 18/20, Accuracy: 66.82%
# Epoch 19/20, Accuracy: 64.91%
# Epoch 20/20, Accuracy: 66.01%
# Model 11 best accuracy: 66.82%
#
# Training model 12/20
# Epoch 1/20, Accuracy: 47.11%
# Epoch 2/20, Accuracy: 53.95%
# Epoch 3/20, Accuracy: 57.47%
# Epoch 4/20, Accuracy: 58.54%
# Epoch 5/20, Accuracy: 60.24%
# Epoch 6/20, Accuracy: 61.69%
# Epoch 7/20, Accuracy: 61.61%
# Epoch 8/20, Accuracy: 62.61%
# Epoch 9/20, Accuracy: 63.23%
# Epoch 10/20, Accuracy: 63.97%
# Epoch 11/20, Accuracy: 64.11%
# Epoch 12/20, Accuracy: 64.37%
# Epoch 13/20, Accuracy: 64.96%
# Epoch 14/20, Accuracy: 65.75%
# Epoch 15/20, Accuracy: 66.15%
# Epoch 16/20, Accuracy: 65.37%
# Epoch 17/20, Accuracy: 66.70%
# Epoch 18/20, Accuracy: 67.03%
# Epoch 19/20, Accuracy: 66.36%
# Epoch 20/20, Accuracy: 66.85%
# Model 12 best accuracy: 67.03%
#
# Training model 13/20
# Epoch 1/20, Accuracy: 48.31%
# Epoch 2/20, Accuracy: 56.28%
# Epoch 3/20, Accuracy: 58.38%
# Epoch 4/20, Accuracy: 59.27%
# Epoch 5/20, Accuracy: 61.07%
# Epoch 6/20, Accuracy: 62.33%
# Epoch 7/20, Accuracy: 63.18%
# Epoch 8/20, Accuracy: 63.27%
# Epoch 9/20, Accuracy: 64.61%
# Epoch 10/20, Accuracy: 63.65%
# Epoch 11/20, Accuracy: 64.49%
# Epoch 12/20, Accuracy: 64.70%
# Epoch 13/20, Accuracy: 65.29%
# Epoch 14/20, Accuracy: 65.13%
# Epoch 15/20, Accuracy: 66.39%
# Epoch 16/20, Accuracy: 66.67%
# Epoch 17/20, Accuracy: 66.39%
# Epoch 18/20, Accuracy: 66.77%
# Epoch 19/20, Accuracy: 66.73%
# Epoch 20/20, Accuracy: 66.01%
# Model 13 best accuracy: 66.77%
#
# Training model 14/20
# Epoch 1/20, Accuracy: 49.67%
# Epoch 2/20, Accuracy: 55.19%
# Epoch 3/20, Accuracy: 57.71%
# Epoch 4/20, Accuracy: 59.16%
# Epoch 5/20, Accuracy: 60.49%
# Epoch 6/20, Accuracy: 60.75%
# Epoch 7/20, Accuracy: 62.49%
# Epoch 8/20, Accuracy: 62.37%
# Epoch 9/20, Accuracy: 62.74%
# Epoch 10/20, Accuracy: 62.66%
# Epoch 11/20, Accuracy: 63.38%
# Epoch 12/20, Accuracy: 63.89%
# Epoch 13/20, Accuracy: 65.65%
# Epoch 14/20, Accuracy: 65.03%
# Epoch 15/20, Accuracy: 64.79%
# Epoch 16/20, Accuracy: 66.11%
# Epoch 17/20, Accuracy: 66.01%
# Epoch 18/20, Accuracy: 65.58%
# Epoch 19/20, Accuracy: 66.48%
# Epoch 20/20, Accuracy: 65.91%
# Model 14 best accuracy: 66.48%
#
# Training model 15/20
# Epoch 1/20, Accuracy: 49.22%
# Epoch 2/20, Accuracy: 55.22%
# Epoch 3/20, Accuracy: 58.42%
# Epoch 4/20, Accuracy: 59.54%
# Epoch 5/20, Accuracy: 61.67%
# Epoch 6/20, Accuracy: 61.51%
# Epoch 7/20, Accuracy: 63.10%
# Epoch 8/20, Accuracy: 64.30%
# Epoch 9/20, Accuracy: 63.54%
# Epoch 10/20, Accuracy: 64.23%
# Epoch 11/20, Accuracy: 64.99%
# Epoch 12/20, Accuracy: 65.61%
# Epoch 13/20, Accuracy: 66.30%
# Epoch 14/20, Accuracy: 65.81%
# Epoch 15/20, Accuracy: 65.29%
# Epoch 16/20, Accuracy: 66.49%
# Epoch 17/20, Accuracy: 66.93%
# Epoch 18/20, Accuracy: 67.12%
# Epoch 19/20, Accuracy: 67.11%
# Epoch 20/20, Accuracy: 66.79%
# Model 15 best accuracy: 67.12%
#
# Training model 16/20
# Epoch 1/20, Accuracy: 51.28%
# Epoch 2/20, Accuracy: 55.94%
# Epoch 3/20, Accuracy: 59.47%
# Epoch 4/20, Accuracy: 59.63%
# Epoch 5/20, Accuracy: 61.67%
# Epoch 6/20, Accuracy: 61.31%
# Epoch 7/20, Accuracy: 63.05%
# Epoch 8/20, Accuracy: 64.00%
# Epoch 9/20, Accuracy: 63.44%
# Epoch 10/20, Accuracy: 64.18%
# Epoch 11/20, Accuracy: 64.50%
# Epoch 12/20, Accuracy: 64.73%
# Epoch 13/20, Accuracy: 65.71%
# Epoch 14/20, Accuracy: 66.80%
# Epoch 15/20, Accuracy: 65.81%
# Epoch 16/20, Accuracy: 66.73%
# Epoch 17/20, Accuracy: 67.02%
# Epoch 18/20, Accuracy: 66.07%
# Epoch 19/20, Accuracy: 66.92%
# Epoch 20/20, Accuracy: 66.19%
# Early stopping at epoch 20
# Model 16 best accuracy: 67.02%
#
# Training model 17/20
# Epoch 1/20, Accuracy: 44.17%
# Epoch 2/20, Accuracy: 48.62%
# Epoch 3/20, Accuracy: 55.12%
# Epoch 4/20, Accuracy: 57.23%
# Epoch 5/20, Accuracy: 58.78%
# Epoch 6/20, Accuracy: 58.97%
# Epoch 7/20, Accuracy: 61.54%
# Epoch 8/20, Accuracy: 61.54%
# Epoch 9/20, Accuracy: 62.54%
# Epoch 10/20, Accuracy: 62.06%
# Epoch 11/20, Accuracy: 62.73%
# Epoch 12/20, Accuracy: 63.80%
# Epoch 13/20, Accuracy: 63.94%
# Epoch 14/20, Accuracy: 64.82%
# Epoch 15/20, Accuracy: 64.74%
# Epoch 16/20, Accuracy: 65.12%
# Epoch 17/20, Accuracy: 65.46%
# Epoch 18/20, Accuracy: 65.92%
# Epoch 19/20, Accuracy: 66.00%
# Epoch 20/20, Accuracy: 66.84%
# Model 17 best accuracy: 66.84%
#
# Training model 18/20
# Epoch 1/20, Accuracy: 47.84%
# Epoch 2/20, Accuracy: 52.48%
# Epoch 3/20, Accuracy: 55.94%
# Epoch 4/20, Accuracy: 57.46%
# Epoch 5/20, Accuracy: 58.22%
# Epoch 6/20, Accuracy: 59.71%
# Epoch 7/20, Accuracy: 61.83%
# Epoch 8/20, Accuracy: 62.24%
# Epoch 9/20, Accuracy: 62.55%
# Epoch 10/20, Accuracy: 63.47%
# Epoch 11/20, Accuracy: 63.06%
# Epoch 12/20, Accuracy: 64.07%
# Epoch 13/20, Accuracy: 64.67%
# Epoch 14/20, Accuracy: 64.34%
# Epoch 15/20, Accuracy: 66.18%
# Epoch 16/20, Accuracy: 65.05%
# Epoch 17/20, Accuracy: 66.27%
# Epoch 18/20, Accuracy: 66.42%
# Epoch 19/20, Accuracy: 66.08%
# Epoch 20/20, Accuracy: 67.23%
# Model 18 best accuracy: 67.23%
#
# Training model 19/20
# Epoch 1/20, Accuracy: 53.06%
# Epoch 2/20, Accuracy: 56.01%
# Epoch 3/20, Accuracy: 59.06%
# Epoch 4/20, Accuracy: 60.24%
# Epoch 5/20, Accuracy: 61.50%
# Epoch 6/20, Accuracy: 61.98%
# Epoch 7/20, Accuracy: 63.53%
# Epoch 8/20, Accuracy: 63.85%
# Epoch 9/20, Accuracy: 63.92%
# Epoch 10/20, Accuracy: 65.96%
# Epoch 11/20, Accuracy: 64.86%
# Epoch 12/20, Accuracy: 65.92%
# Epoch 13/20, Accuracy: 66.17%
# Epoch 14/20, Accuracy: 66.19%
# Epoch 15/20, Accuracy: 66.36%
# Epoch 16/20, Accuracy: 66.71%
# Epoch 17/20, Accuracy: 67.61%
# Epoch 18/20, Accuracy: 67.96%
# Epoch 19/20, Accuracy: 67.09%
# Epoch 20/20, Accuracy: 68.12%
# Model 19 best accuracy: 68.12%
#
# Training model 20/20
# Epoch 1/20, Accuracy: 47.90%
# Epoch 2/20, Accuracy: 54.46%
# Epoch 3/20, Accuracy: 57.08%
# Epoch 4/20, Accuracy: 59.76%
# Epoch 5/20, Accuracy: 60.26%
# Epoch 6/20, Accuracy: 62.25%
# Epoch 7/20, Accuracy: 61.88%
# Epoch 8/20, Accuracy: 62.57%
# Epoch 9/20, Accuracy: 63.63%
# Epoch 10/20, Accuracy: 64.14%
# Epoch 11/20, Accuracy: 64.57%
# Epoch 12/20, Accuracy: 64.73%
# Epoch 13/20, Accuracy: 65.22%
# Epoch 14/20, Accuracy: 65.20%
# Epoch 15/20, Accuracy: 65.09%
# Epoch 16/20, Accuracy: 65.79%
# Epoch 17/20, Accuracy: 65.96%
# Epoch 18/20, Accuracy: 66.23%
# Epoch 19/20, Accuracy: 66.15%
# Epoch 20/20, Accuracy: 65.28%
# Model 20 best accuracy: 66.23%

# %%
# Cell 5: Model Saving
def save_ensemble(ensemble, directory='best_boi_models'):
    if not os.path.exists(directory):
        os.makedirs(directory)
    
    for i, (model, accuracy) in enumerate(ensemble):
        model_path = os.path.join(directory, f'model_{i+1}_acc_{accuracy:.2f}.pth')
        torch.save(model.state_dict(), model_path)
        print(f"Model {i+1} saved to {model_path}")

save_ensemble(ensemble)
# Out:
# Model 1 saved to best_boi_models\model_1_acc_66.54.pth
# Model 2 saved to best_boi_models\model_2_acc_66.34.pth
# Model 3 saved to best_boi_models\model_3_acc_67.64.pth
# Model 4 saved to best_boi_models\model_4_acc_66.18.pth
# Model 5 saved to best_boi_models\model_5_acc_66.35.pth
# Model 6 saved to best_boi_models\model_6_acc_67.36.pth
# Model 7 saved to best_boi_models\model_7_acc_68.04.pth
# Model 8 saved to best_boi_models\model_8_acc_66.93.pth
# Model 9 saved to best_boi_models\model_9_acc_67.54.pth
# Model 10 saved to best_boi_models\model_10_acc_67.35.pth
# Model 11 saved to best_boi_models\model_11_acc_66.82.pth
# Model 12 saved to best_boi_models\model_12_acc_67.03.pth
# Model 13 saved to best_boi_models\model_13_acc_66.77.pth
# Model 14 saved to best_boi_models\model_14_acc_66.48.pth
# Model 15 saved to best_boi_models\model_15_acc_67.12.pth
# Model 16 saved to best_boi_models\model_16_acc_67.02.pth
# Model 17 saved to best_boi_models\model_17_acc_66.84.pth
# Model 18 saved to best_boi_models\model_18_acc_67.23.pth
# Model 19 saved to best_boi_models\model_19_acc_68.12.pth
# Model 20 saved to best_boi_models\model_20_acc_66.23.pth
