# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os
import re

PIXEL_SIZE = 16

def generate_whitenoise_image():
    return np.random.randint(0, 256, PIXEL_SIZE * PIXEL_SIZE)

def calculate_similarity(vec1, vec2):
    return np.sum((vec1 - vec2) ** 2)

def run_experiment(target_image, num_trials):
    all_images = []
    
    for _ in range(num_trials):
        stimuli = [generate_whitenoise_image() for _ in range(10)]
        similarities = [calculate_similarity(target_image, stim) for stim in stimuli]
        most_similar_index = np.argmin(similarities)
        
        selected_image = stimuli[most_similar_index]
        all_images.append(selected_image)
    
    return all_images

def create_composite_image(images):
    composite = np.mean(images, axis=0)
    return ((composite - composite.min()) / (composite.max() - composite.min()) * 255).astype(np.uint8)

def load_target_image(image_path):
    img = Image.open(image_path).convert('L')  # Convert to grayscale
    img = img.resize((PIXEL_SIZE, PIXEL_SIZE), Image.LANCZOS)
    return np.array(img).flatten()

def process_and_save_images(folder_name, file_pattern, num_trials):
    output_folder = f"composite_images_{num_trials}_trials"
    os.makedirs(output_folder, exist_ok=True)
    for filename in os.listdir(folder_name):
        if filename.endswith('.png'):
            match = re.match(file_pattern, filename)
            if match:
                image_path = os.path.join(folder_name, filename)
                target_image = load_target_image(image_path)
                experiment_results = run_experiment(target_image, num_trials)
                composite = create_composite_image(experiment_results)
                
                output_filename = f"composite_{filename}"
                output_path = os.path.join(output_folder, output_filename)
                Image.fromarray(composite.reshape((PIXEL_SIZE, PIXEL_SIZE))).save(output_path)
                
                print(f"Saved composite for {image_path} with {num_trials} trials")

# Run the experiment for 50, 100, and 200 trials
for num_trials in [50, 75, 100, 200, 400, 800, 2000]:
    print(f"\nRunning experiment with {num_trials} trials:")
    
    # Process original digits
    process_and_save_images("original_digit_images", r"digit_(\d+)\.png", num_trials)

    # Process cursive digits
    process_and_save_images("cursive_digit_images", r"digit_(\d+)_cursive\.png", num_trials)

    # Process rotated digits with any angle
    process_and_save_images("rotated_digit_images", r"digit_(\d+)_angle_(\d+)\.png", num_trials)

print("\nAll composites have been generated and saved.")
# Out:
# Running experiment with 50 trials:
# Saved composite for original_digit_images\digit_0.png with 50 trials
# Saved composite for original_digit_images\digit_1.png with 50 trials
# Saved composite for original_digit_images\digit_2.png with 50 trials
# Saved composite for original_digit_images\digit_3.png with 50 trials
# Saved composite for original_digit_images\digit_4.png with 50 trials
# Saved composite for original_digit_images\digit_5.png with 50 trials
# Saved composite for original_digit_images\digit_6.png with 50 trials
# Saved composite for original_digit_images\digit_7.png with 50 trials
# Saved composite for original_digit_images\digit_8.png with 50 trials
# Saved composite for original_digit_images\digit_9.png with 50 trials
# Saved composite for cursive_digit_images\digit_0_cursive.png with 50 trials
# Saved composite for cursive_digit_images\digit_1_cursive.png with 50 trials
# Saved composite for cursive_digit_images\digit_2_cursive.png with 50 trials
# Saved composite for cursive_digit_images\digit_3_cursive.png with 50 trials
# Saved composite for cursive_digit_images\digit_4_cursive.png with 50 trials
# Saved composite for cursive_digit_images\digit_5_cursive.png with 50 trials
# Saved composite for cursive_digit_images\digit_6_cursive.png with 50 trials
# Saved composite for cursive_digit_images\digit_7_cursive.png with 50 trials
# Saved composite for cursive_digit_images\digit_8_cursive.png with 50 trials
# Saved composite for cursive_digit_images\digit_9_cursive.png with 50 trials
# Saved composite for rotated_digit_images\digit_0_angle_22.png with 50 trials
# Saved composite for rotated_digit_images\digit_0_angle_262.png with 50 trials
# Saved composite for rotated_digit_images\digit_0_angle_287.png with 50 trials
# Saved composite for rotated_digit_images\digit_0_angle_39.png with 50 trials
# Saved composite for rotated_digit_images\digit_0_angle_70.png with 50 trials
# Saved composite for rotated_digit_images\digit_0_angle_76.png with 50 trials
# Saved composite for rotated_digit_images\digit_1_angle_280.png with 50 trials
# Saved composite for rotated_digit_images\digit_1_angle_288.png with 50 trials
# Saved composite for rotated_digit_images\digit_1_angle_30.png with 50 trials
# Saved composite for rotated_digit_images\digit_1_angle_35.png with 50 trials
# Saved composite for rotated_digit_images\digit_1_angle_62.png with 50 trials
# Saved composite for rotated_digit_images\digit_1_angle_65.png with 50 trials
# Saved composite for rotated_digit_images\digit_2_angle_25.png with 50 trials
# Saved composite for rotated_digit_images\digit_2_angle_285.png with 50 trials
# Saved composite for rotated_digit_images\digit_2_angle_289.png with 50 trials
# Saved composite for rotated_digit_images\digit_2_angle_31.png with 50 trials
# Saved composite for rotated_digit_images\digit_2_angle_72.png with 50 trials
# Saved composite for rotated_digit_images\digit_2_angle_77.png with 50 trials
# Saved composite for rotated_digit_images\digit_3_angle_26.png with 50 trials
# Saved composite for rotated_digit_images\digit_3_angle_267.png with 50 trials
# Saved composite for rotated_digit_images\digit_3_angle_27.png with 50 trials
# Saved composite for rotated_digit_images\digit_3_angle_290.png with 50 trials
# Saved composite for rotated_digit_images\digit_3_angle_75.png with 50 trials
# Saved composite for rotated_digit_images\digit_3_angle_79.png with 50 trials
# Saved composite for rotated_digit_images\digit_4_angle_23.png with 50 trials
# Saved composite for rotated_digit_images\digit_4_angle_26.png with 50 trials
# Saved composite for rotated_digit_images\digit_4_angle_264.png with 50 trials
# Saved composite for rotated_digit_images\digit_4_angle_286.png with 50 trials
# Saved composite for rotated_digit_images\digit_4_angle_72.png with 50 trials
# Saved composite for rotated_digit_images\digit_4_angle_76.png with 50 trials
# Saved composite for rotated_digit_images\digit_5_angle_270.png with 50 trials
# Saved composite for rotated_digit_images\digit_5_angle_279.png with 50 trials
# Saved composite for rotated_digit_images\digit_5_angle_38.png with 50 trials
# Saved composite for rotated_digit_images\digit_5_angle_39.png with 50 trials
# Saved composite for rotated_digit_images\digit_5_angle_66.png with 50 trials
# Saved composite for rotated_digit_images\digit_5_angle_67.png with 50 trials
# Saved composite for rotated_digit_images\digit_6_angle_26.png with 50 trials
# Saved composite for rotated_digit_images\digit_6_angle_284.png with 50 trials
# Saved composite for rotated_digit_images\digit_6_angle_285.png with 50 trials
# Saved composite for rotated_digit_images\digit_6_angle_39.png with 50 trials
# Saved composite for rotated_digit_images\digit_6_angle_63.png with 50 trials
# Saved composite for rotated_digit_images\digit_6_angle_73.png with 50 trials
# Saved composite for rotated_digit_images\digit_7_angle_20.png with 50 trials
# Saved composite for rotated_digit_images\digit_7_angle_280.png with 50 trials
# Saved composite for rotated_digit_images\digit_7_angle_38.png with 50 trials
# Saved composite for rotated_digit_images\digit_7_angle_63.png with 50 trials
# Saved composite for rotated_digit_images\digit_7_angle_74.png with 50 trials
# Saved composite for rotated_digit_images\digit_8_angle_27.png with 50 trials
# Saved composite for rotated_digit_images\digit_8_angle_286.png with 50 trials
# Saved composite for rotated_digit_images\digit_8_angle_287.png with 50 trials
# Saved composite for rotated_digit_images\digit_8_angle_31.png with 50 trials
# Saved composite for rotated_digit_images\digit_8_angle_70.png with 50 trials
# Saved composite for rotated_digit_images\digit_8_angle_77.png with 50 trials
# Saved composite for rotated_digit_images\digit_9_angle_21.png with 50 trials
# Saved composite for rotated_digit_images\digit_9_angle_276.png with 50 trials
# Saved composite for rotated_digit_images\digit_9_angle_278.png with 50 trials
# Saved composite for rotated_digit_images\digit_9_angle_35.png with 50 trials
# Saved composite for rotated_digit_images\digit_9_angle_70.png with 50 trials
# Saved composite for rotated_digit_images\digit_9_angle_71.png with 50 trials
#
# Running experiment with 75 trials:
# Saved composite for original_digit_images\digit_0.png with 75 trials
# Saved composite for original_digit_images\digit_1.png with 75 trials
# Saved composite for original_digit_images\digit_2.png with 75 trials
# Saved composite for original_digit_images\digit_3.png with 75 trials
# Saved composite for original_digit_images\digit_4.png with 75 trials
# Saved composite for original_digit_images\digit_5.png with 75 trials
# Saved composite for original_digit_images\digit_6.png with 75 trials
# Saved composite for original_digit_images\digit_7.png with 75 trials
# Saved composite for original_digit_images\digit_8.png with 75 trials
# Saved composite for original_digit_images\digit_9.png with 75 trials
# Saved composite for cursive_digit_images\digit_0_cursive.png with 75 trials
# Saved composite for cursive_digit_images\digit_1_cursive.png with 75 trials
# Saved composite for cursive_digit_images\digit_2_cursive.png with 75 trials
# Saved composite for cursive_digit_images\digit_3_cursive.png with 75 trials
# Saved composite for cursive_digit_images\digit_4_cursive.png with 75 trials
# Saved composite for cursive_digit_images\digit_5_cursive.png with 75 trials
# Saved composite for cursive_digit_images\digit_6_cursive.png with 75 trials
# Saved composite for cursive_digit_images\digit_7_cursive.png with 75 trials
# Saved composite for cursive_digit_images\digit_8_cursive.png with 75 trials
# Saved composite for cursive_digit_images\digit_9_cursive.png with 75 trials
# Saved composite for rotated_digit_images\digit_0_angle_22.png with 75 trials
# Saved composite for rotated_digit_images\digit_0_angle_262.png with 75 trials
# Saved composite for rotated_digit_images\digit_0_angle_287.png with 75 trials
# Saved composite for rotated_digit_images\digit_0_angle_39.png with 75 trials
# Saved composite for rotated_digit_images\digit_0_angle_70.png with 75 trials
# Saved composite for rotated_digit_images\digit_0_angle_76.png with 75 trials
# Saved composite for rotated_digit_images\digit_1_angle_280.png with 75 trials
# Saved composite for rotated_digit_images\digit_1_angle_288.png with 75 trials
# Saved composite for rotated_digit_images\digit_1_angle_30.png with 75 trials
# Saved composite for rotated_digit_images\digit_1_angle_35.png with 75 trials
# Saved composite for rotated_digit_images\digit_1_angle_62.png with 75 trials
# Saved composite for rotated_digit_images\digit_1_angle_65.png with 75 trials
# Saved composite for rotated_digit_images\digit_2_angle_25.png with 75 trials
# Saved composite for rotated_digit_images\digit_2_angle_285.png with 75 trials
# Saved composite for rotated_digit_images\digit_2_angle_289.png with 75 trials
# Saved composite for rotated_digit_images\digit_2_angle_31.png with 75 trials
# Saved composite for rotated_digit_images\digit_2_angle_72.png with 75 trials
# Saved composite for rotated_digit_images\digit_2_angle_77.png with 75 trials
# Saved composite for rotated_digit_images\digit_3_angle_26.png with 75 trials
# Saved composite for rotated_digit_images\digit_3_angle_267.png with 75 trials
# Saved composite for rotated_digit_images\digit_3_angle_27.png with 75 trials
# Saved composite for rotated_digit_images\digit_3_angle_290.png with 75 trials
# Saved composite for rotated_digit_images\digit_3_angle_75.png with 75 trials
# Saved composite for rotated_digit_images\digit_3_angle_79.png with 75 trials
# Saved composite for rotated_digit_images\digit_4_angle_23.png with 75 trials
# Saved composite for rotated_digit_images\digit_4_angle_26.png with 75 trials
# Saved composite for rotated_digit_images\digit_4_angle_264.png with 75 trials
# Saved composite for rotated_digit_images\digit_4_angle_286.png with 75 trials
# Saved composite for rotated_digit_images\digit_4_angle_72.png with 75 trials
# Saved composite for rotated_digit_images\digit_4_angle_76.png with 75 trials
# Saved composite for rotated_digit_images\digit_5_angle_270.png with 75 trials
# Saved composite for rotated_digit_images\digit_5_angle_279.png with 75 trials
# Saved composite for rotated_digit_images\digit_5_angle_38.png with 75 trials
# Saved composite for rotated_digit_images\digit_5_angle_39.png with 75 trials
# Saved composite for rotated_digit_images\digit_5_angle_66.png with 75 trials
# Saved composite for rotated_digit_images\digit_5_angle_67.png with 75 trials
# Saved composite for rotated_digit_images\digit_6_angle_26.png with 75 trials
# Saved composite for rotated_digit_images\digit_6_angle_284.png with 75 trials
# Saved composite for rotated_digit_images\digit_6_angle_285.png with 75 trials
# Saved composite for rotated_digit_images\digit_6_angle_39.png with 75 trials
# Saved composite for rotated_digit_images\digit_6_angle_63.png with 75 trials
# Saved composite for rotated_digit_images\digit_6_angle_73.png with 75 trials
# Saved composite for rotated_digit_images\digit_7_angle_20.png with 75 trials
# Saved composite for rotated_digit_images\digit_7_angle_280.png with 75 trials
# Saved composite for rotated_digit_images\digit_7_angle_38.png with 75 trials
# Saved composite for rotated_digit_images\digit_7_angle_63.png with 75 trials
# Saved composite for rotated_digit_images\digit_7_angle_74.png with 75 trials
# Saved composite for rotated_digit_images\digit_8_angle_27.png with 75 trials
# Saved composite for rotated_digit_images\digit_8_angle_286.png with 75 trials
# Saved composite for rotated_digit_images\digit_8_angle_287.png with 75 trials
# Saved composite for rotated_digit_images\digit_8_angle_31.png with 75 trials
# Saved composite for rotated_digit_images\digit_8_angle_70.png with 75 trials
# Saved composite for rotated_digit_images\digit_8_angle_77.png with 75 trials
# Saved composite for rotated_digit_images\digit_9_angle_21.png with 75 trials
# Saved composite for rotated_digit_images\digit_9_angle_276.png with 75 trials
# Saved composite for rotated_digit_images\digit_9_angle_278.png with 75 trials
# Saved composite for rotated_digit_images\digit_9_angle_35.png with 75 trials
# Saved composite for rotated_digit_images\digit_9_angle_70.png with 75 trials
# Saved composite for rotated_digit_images\digit_9_angle_71.png with 75 trials
#
# Running experiment with 100 trials:
# Saved composite for original_digit_images\digit_0.png with 100 trials
# Saved composite for original_digit_images\digit_1.png with 100 trials
# Saved composite for original_digit_images\digit_2.png with 100 trials
# Saved composite for original_digit_images\digit_3.png with 100 trials
# Saved composite for original_digit_images\digit_4.png with 100 trials
# Saved composite for original_digit_images\digit_5.png with 100 trials
# Saved composite for original_digit_images\digit_6.png with 100 trials
# Saved composite for original_digit_images\digit_7.png with 100 trials
# Saved composite for original_digit_images\digit_8.png with 100 trials
# Saved composite for original_digit_images\digit_9.png with 100 trials
# Saved composite for cursive_digit_images\digit_0_cursive.png with 100 trials
# Saved composite for cursive_digit_images\digit_1_cursive.png with 100 trials
# Saved composite for cursive_digit_images\digit_2_cursive.png with 100 trials
# Saved composite for cursive_digit_images\digit_3_cursive.png with 100 trials
# Saved composite for cursive_digit_images\digit_4_cursive.png with 100 trials
# Saved composite for cursive_digit_images\digit_5_cursive.png with 100 trials
# Saved composite for cursive_digit_images\digit_6_cursive.png with 100 trials
# Saved composite for cursive_digit_images\digit_7_cursive.png with 100 trials
# Saved composite for cursive_digit_images\digit_8_cursive.png with 100 trials
# Saved composite for cursive_digit_images\digit_9_cursive.png with 100 trials
# Saved composite for rotated_digit_images\digit_0_angle_22.png with 100 trials
# Saved composite for rotated_digit_images\digit_0_angle_262.png with 100 trials
# Saved composite for rotated_digit_images\digit_0_angle_287.png with 100 trials
# Saved composite for rotated_digit_images\digit_0_angle_39.png with 100 trials
# Saved composite for rotated_digit_images\digit_0_angle_70.png with 100 trials
# Saved composite for rotated_digit_images\digit_0_angle_76.png with 100 trials
# Saved composite for rotated_digit_images\digit_1_angle_280.png with 100 trials
# Saved composite for rotated_digit_images\digit_1_angle_288.png with 100 trials
# Saved composite for rotated_digit_images\digit_1_angle_30.png with 100 trials
# Saved composite for rotated_digit_images\digit_1_angle_35.png with 100 trials
# Saved composite for rotated_digit_images\digit_1_angle_62.png with 100 trials
# Saved composite for rotated_digit_images\digit_1_angle_65.png with 100 trials
# Saved composite for rotated_digit_images\digit_2_angle_25.png with 100 trials
# Saved composite for rotated_digit_images\digit_2_angle_285.png with 100 trials
# Saved composite for rotated_digit_images\digit_2_angle_289.png with 100 trials
# Saved composite for rotated_digit_images\digit_2_angle_31.png with 100 trials
# Saved composite for rotated_digit_images\digit_2_angle_72.png with 100 trials
# Saved composite for rotated_digit_images\digit_2_angle_77.png with 100 trials
# Saved composite for rotated_digit_images\digit_3_angle_26.png with 100 trials
# Saved composite for rotated_digit_images\digit_3_angle_267.png with 100 trials
# Saved composite for rotated_digit_images\digit_3_angle_27.png with 100 trials
# Saved composite for rotated_digit_images\digit_3_angle_290.png with 100 trials
# Saved composite for rotated_digit_images\digit_3_angle_75.png with 100 trials
# Saved composite for rotated_digit_images\digit_3_angle_79.png with 100 trials
# Saved composite for rotated_digit_images\digit_4_angle_23.png with 100 trials
# Saved composite for rotated_digit_images\digit_4_angle_26.png with 100 trials
# Saved composite for rotated_digit_images\digit_4_angle_264.png with 100 trials
# Saved composite for rotated_digit_images\digit_4_angle_286.png with 100 trials
# Saved composite for rotated_digit_images\digit_4_angle_72.png with 100 trials
# Saved composite for rotated_digit_images\digit_4_angle_76.png with 100 trials
# Saved composite for rotated_digit_images\digit_5_angle_270.png with 100 trials
# Saved composite for rotated_digit_images\digit_5_angle_279.png with 100 trials
# Saved composite for rotated_digit_images\digit_5_angle_38.png with 100 trials
# Saved composite for rotated_digit_images\digit_5_angle_39.png with 100 trials
# Saved composite for rotated_digit_images\digit_5_angle_66.png with 100 trials
# Saved composite for rotated_digit_images\digit_5_angle_67.png with 100 trials
# Saved composite for rotated_digit_images\digit_6_angle_26.png with 100 trials
# Saved composite for rotated_digit_images\digit_6_angle_284.png with 100 trials
# Saved composite for rotated_digit_images\digit_6_angle_285.png with 100 trials
# Saved composite for rotated_digit_images\digit_6_angle_39.png with 100 trials
# Saved composite for rotated_digit_images\digit_6_angle_63.png with 100 trials
# Saved composite for rotated_digit_images\digit_6_angle_73.png with 100 trials
# Saved composite for rotated_digit_images\digit_7_angle_20.png with 100 trials
# Saved composite for rotated_digit_images\digit_7_angle_280.png with 100 trials
# Saved composite for rotated_digit_images\digit_7_angle_38.png with 100 trials
# Saved composite for rotated_digit_images\digit_7_angle_63.png with 100 trials
# Saved composite for rotated_digit_images\digit_7_angle_74.png with 100 trials
# Saved composite for rotated_digit_images\digit_8_angle_27.png with 100 trials
# Saved composite for rotated_digit_images\digit_8_angle_286.png with 100 trials
# Saved composite for rotated_digit_images\digit_8_angle_287.png with 100 trials
# Saved composite for rotated_digit_images\digit_8_angle_31.png with 100 trials
# Saved composite for rotated_digit_images\digit_8_angle_70.png with 100 trials
# Saved composite for rotated_digit_images\digit_8_angle_77.png with 100 trials
# Saved composite for rotated_digit_images\digit_9_angle_21.png with 100 trials
# Saved composite for rotated_digit_images\digit_9_angle_276.png with 100 trials
# Saved composite for rotated_digit_images\digit_9_angle_278.png with 100 trials
# Saved composite for rotated_digit_images\digit_9_angle_35.png with 100 trials
# Saved composite for rotated_digit_images\digit_9_angle_70.png with 100 trials
# Saved composite for rotated_digit_images\digit_9_angle_71.png with 100 trials
#
# Running experiment with 200 trials:
# Saved composite for original_digit_images\digit_0.png with 200 trials
# Saved composite for original_digit_images\digit_1.png with 200 trials
# Saved composite for original_digit_images\digit_2.png with 200 trials
# Saved composite for original_digit_images\digit_3.png with 200 trials
# Saved composite for original_digit_images\digit_4.png with 200 trials
# Saved composite for original_digit_images\digit_5.png with 200 trials
# Saved composite for original_digit_images\digit_6.png with 200 trials
# Saved composite for original_digit_images\digit_7.png with 200 trials
# Saved composite for original_digit_images\digit_8.png with 200 trials
# Saved composite for original_digit_images\digit_9.png with 200 trials
# Saved composite for cursive_digit_images\digit_0_cursive.png with 200 trials
# Saved composite for cursive_digit_images\digit_1_cursive.png with 200 trials
# Saved composite for cursive_digit_images\digit_2_cursive.png with 200 trials
# Saved composite for cursive_digit_images\digit_3_cursive.png with 200 trials
# Saved composite for cursive_digit_images\digit_4_cursive.png with 200 trials
# Saved composite for cursive_digit_images\digit_5_cursive.png with 200 trials
# Saved composite for cursive_digit_images\digit_6_cursive.png with 200 trials
# Saved composite for cursive_digit_images\digit_7_cursive.png with 200 trials
# Saved composite for cursive_digit_images\digit_8_cursive.png with 200 trials
# Saved composite for cursive_digit_images\digit_9_cursive.png with 200 trials
# Saved composite for rotated_digit_images\digit_0_angle_22.png with 200 trials
# Saved composite for rotated_digit_images\digit_0_angle_262.png with 200 trials
# Saved composite for rotated_digit_images\digit_0_angle_287.png with 200 trials
# Saved composite for rotated_digit_images\digit_0_angle_39.png with 200 trials
# Saved composite for rotated_digit_images\digit_0_angle_70.png with 200 trials
# Saved composite for rotated_digit_images\digit_0_angle_76.png with 200 trials
# Saved composite for rotated_digit_images\digit_1_angle_280.png with 200 trials
# Saved composite for rotated_digit_images\digit_1_angle_288.png with 200 trials
# Saved composite for rotated_digit_images\digit_1_angle_30.png with 200 trials
# Saved composite for rotated_digit_images\digit_1_angle_35.png with 200 trials
# Saved composite for rotated_digit_images\digit_1_angle_62.png with 200 trials
# Saved composite for rotated_digit_images\digit_1_angle_65.png with 200 trials
# Saved composite for rotated_digit_images\digit_2_angle_25.png with 200 trials
# Saved composite for rotated_digit_images\digit_2_angle_285.png with 200 trials
# Saved composite for rotated_digit_images\digit_2_angle_289.png with 200 trials
# Saved composite for rotated_digit_images\digit_2_angle_31.png with 200 trials
# Saved composite for rotated_digit_images\digit_2_angle_72.png with 200 trials
# Saved composite for rotated_digit_images\digit_2_angle_77.png with 200 trials
# Saved composite for rotated_digit_images\digit_3_angle_26.png with 200 trials
# Saved composite for rotated_digit_images\digit_3_angle_267.png with 200 trials
# Saved composite for rotated_digit_images\digit_3_angle_27.png with 200 trials
# Saved composite for rotated_digit_images\digit_3_angle_290.png with 200 trials
# Saved composite for rotated_digit_images\digit_3_angle_75.png with 200 trials
# Saved composite for rotated_digit_images\digit_3_angle_79.png with 200 trials
# Saved composite for rotated_digit_images\digit_4_angle_23.png with 200 trials
# Saved composite for rotated_digit_images\digit_4_angle_26.png with 200 trials
# Saved composite for rotated_digit_images\digit_4_angle_264.png with 200 trials
# Saved composite for rotated_digit_images\digit_4_angle_286.png with 200 trials
# Saved composite for rotated_digit_images\digit_4_angle_72.png with 200 trials
# Saved composite for rotated_digit_images\digit_4_angle_76.png with 200 trials
# Saved composite for rotated_digit_images\digit_5_angle_270.png with 200 trials
# Saved composite for rotated_digit_images\digit_5_angle_279.png with 200 trials
# Saved composite for rotated_digit_images\digit_5_angle_38.png with 200 trials
# Saved composite for rotated_digit_images\digit_5_angle_39.png with 200 trials
# Saved composite for rotated_digit_images\digit_5_angle_66.png with 200 trials
# Saved composite for rotated_digit_images\digit_5_angle_67.png with 200 trials
# Saved composite for rotated_digit_images\digit_6_angle_26.png with 200 trials
# Saved composite for rotated_digit_images\digit_6_angle_284.png with 200 trials
# Saved composite for rotated_digit_images\digit_6_angle_285.png with 200 trials
# Saved composite for rotated_digit_images\digit_6_angle_39.png with 200 trials
# Saved composite for rotated_digit_images\digit_6_angle_63.png with 200 trials
# Saved composite for rotated_digit_images\digit_6_angle_73.png with 200 trials
# Saved composite for rotated_digit_images\digit_7_angle_20.png with 200 trials
# Saved composite for rotated_digit_images\digit_7_angle_280.png with 200 trials
# Saved composite for rotated_digit_images\digit_7_angle_38.png with 200 trials
# Saved composite for rotated_digit_images\digit_7_angle_63.png with 200 trials
# Saved composite for rotated_digit_images\digit_7_angle_74.png with 200 trials
# Saved composite for rotated_digit_images\digit_8_angle_27.png with 200 trials
# Saved composite for rotated_digit_images\digit_8_angle_286.png with 200 trials
# Saved composite for rotated_digit_images\digit_8_angle_287.png with 200 trials
# Saved composite for rotated_digit_images\digit_8_angle_31.png with 200 trials
# Saved composite for rotated_digit_images\digit_8_angle_70.png with 200 trials
# Saved composite for rotated_digit_images\digit_8_angle_77.png with 200 trials
# Saved composite for rotated_digit_images\digit_9_angle_21.png with 200 trials
# Saved composite for rotated_digit_images\digit_9_angle_276.png with 200 trials
# Saved composite for rotated_digit_images\digit_9_angle_278.png with 200 trials
# Saved composite for rotated_digit_images\digit_9_angle_35.png with 200 trials
# Saved composite for rotated_digit_images\digit_9_angle_70.png with 200 trials
# Saved composite for rotated_digit_images\digit_9_angle_71.png with 200 trials
#
# Running experiment with 400 trials:
# Saved composite for original_digit_images\digit_0.png with 400 trials
# Saved composite for original_digit_images\digit_1.png with 400 trials
# Saved composite for original_digit_images\digit_2.png with 400 trials
# Saved composite for original_digit_images\digit_3.png with 400 trials
# Saved composite for original_digit_images\digit_4.png with 400 trials
# Saved composite for original_digit_images\digit_5.png with 400 trials
# Saved composite for original_digit_images\digit_6.png with 400 trials
# Saved composite for original_digit_images\digit_7.png with 400 trials
# Saved composite for original_digit_images\digit_8.png with 400 trials
# Saved composite for original_digit_images\digit_9.png with 400 trials
# Saved composite for cursive_digit_images\digit_0_cursive.png with 400 trials
# Saved composite for cursive_digit_images\digit_1_cursive.png with 400 trials
# Saved composite for cursive_digit_images\digit_2_cursive.png with 400 trials
# Saved composite for cursive_digit_images\digit_3_cursive.png with 400 trials
# Saved composite for cursive_digit_images\digit_4_cursive.png with 400 trials
# Saved composite for cursive_digit_images\digit_5_cursive.png with 400 trials
# Saved composite for cursive_digit_images\digit_6_cursive.png with 400 trials
# Saved composite for cursive_digit_images\digit_7_cursive.png with 400 trials
# Saved composite for cursive_digit_images\digit_8_cursive.png with 400 trials
# Saved composite for cursive_digit_images\digit_9_cursive.png with 400 trials
# Saved composite for rotated_digit_images\digit_0_angle_22.png with 400 trials
# Saved composite for rotated_digit_images\digit_0_angle_262.png with 400 trials
# Saved composite for rotated_digit_images\digit_0_angle_287.png with 400 trials
# Saved composite for rotated_digit_images\digit_0_angle_39.png with 400 trials
# Saved composite for rotated_digit_images\digit_0_angle_70.png with 400 trials
# Saved composite for rotated_digit_images\digit_0_angle_76.png with 400 trials
# Saved composite for rotated_digit_images\digit_1_angle_280.png with 400 trials
# Saved composite for rotated_digit_images\digit_1_angle_288.png with 400 trials
# Saved composite for rotated_digit_images\digit_1_angle_30.png with 400 trials
# Saved composite for rotated_digit_images\digit_1_angle_35.png with 400 trials
# Saved composite for rotated_digit_images\digit_1_angle_62.png with 400 trials
# Saved composite for rotated_digit_images\digit_1_angle_65.png with 400 trials
# Saved composite for rotated_digit_images\digit_2_angle_25.png with 400 trials
# Saved composite for rotated_digit_images\digit_2_angle_285.png with 400 trials
# Saved composite for rotated_digit_images\digit_2_angle_289.png with 400 trials
# Saved composite for rotated_digit_images\digit_2_angle_31.png with 400 trials
# Saved composite for rotated_digit_images\digit_2_angle_72.png with 400 trials
# Saved composite for rotated_digit_images\digit_2_angle_77.png with 400 trials
# Saved composite for rotated_digit_images\digit_3_angle_26.png with 400 trials
# Saved composite for rotated_digit_images\digit_3_angle_267.png with 400 trials
# Saved composite for rotated_digit_images\digit_3_angle_27.png with 400 trials
# Saved composite for rotated_digit_images\digit_3_angle_290.png with 400 trials
# Saved composite for rotated_digit_images\digit_3_angle_75.png with 400 trials
# Saved composite for rotated_digit_images\digit_3_angle_79.png with 400 trials
# Saved composite for rotated_digit_images\digit_4_angle_23.png with 400 trials
# Saved composite for rotated_digit_images\digit_4_angle_26.png with 400 trials
# Saved composite for rotated_digit_images\digit_4_angle_264.png with 400 trials
# Saved composite for rotated_digit_images\digit_4_angle_286.png with 400 trials
# Saved composite for rotated_digit_images\digit_4_angle_72.png with 400 trials
# Saved composite for rotated_digit_images\digit_4_angle_76.png with 400 trials
# Saved composite for rotated_digit_images\digit_5_angle_270.png with 400 trials
# Saved composite for rotated_digit_images\digit_5_angle_279.png with 400 trials
# Saved composite for rotated_digit_images\digit_5_angle_38.png with 400 trials
# Saved composite for rotated_digit_images\digit_5_angle_39.png with 400 trials
# Saved composite for rotated_digit_images\digit_5_angle_66.png with 400 trials
# Saved composite for rotated_digit_images\digit_5_angle_67.png with 400 trials
# Saved composite for rotated_digit_images\digit_6_angle_26.png with 400 trials
# Saved composite for rotated_digit_images\digit_6_angle_284.png with 400 trials
# Saved composite for rotated_digit_images\digit_6_angle_285.png with 400 trials
# Saved composite for rotated_digit_images\digit_6_angle_39.png with 400 trials
# Saved composite for rotated_digit_images\digit_6_angle_63.png with 400 trials
# Saved composite for rotated_digit_images\digit_6_angle_73.png with 400 trials
# Saved composite for rotated_digit_images\digit_7_angle_20.png with 400 trials
# Saved composite for rotated_digit_images\digit_7_angle_280.png with 400 trials
# Saved composite for rotated_digit_images\digit_7_angle_38.png with 400 trials
# Saved composite for rotated_digit_images\digit_7_angle_63.png with 400 trials
# Saved composite for rotated_digit_images\digit_7_angle_74.png with 400 trials
# Saved composite for rotated_digit_images\digit_8_angle_27.png with 400 trials
# Saved composite for rotated_digit_images\digit_8_angle_286.png with 400 trials
# Saved composite for rotated_digit_images\digit_8_angle_287.png with 400 trials
# Saved composite for rotated_digit_images\digit_8_angle_31.png with 400 trials
# Saved composite for rotated_digit_images\digit_8_angle_70.png with 400 trials
# Saved composite for rotated_digit_images\digit_8_angle_77.png with 400 trials
# Saved composite for rotated_digit_images\digit_9_angle_21.png with 400 trials
# Saved composite for rotated_digit_images\digit_9_angle_276.png with 400 trials
# Saved composite for rotated_digit_images\digit_9_angle_278.png with 400 trials
# Saved composite for rotated_digit_images\digit_9_angle_35.png with 400 trials
# Saved composite for rotated_digit_images\digit_9_angle_70.png with 400 trials
# Saved composite for rotated_digit_images\digit_9_angle_71.png with 400 trials
#
# Running experiment with 800 trials:
# Saved composite for original_digit_images\digit_0.png with 800 trials
# Saved composite for original_digit_images\digit_1.png with 800 trials
# Saved composite for original_digit_images\digit_2.png with 800 trials
# Saved composite for original_digit_images\digit_3.png with 800 trials
# Saved composite for original_digit_images\digit_4.png with 800 trials
# Saved composite for original_digit_images\digit_5.png with 800 trials
# Saved composite for original_digit_images\digit_6.png with 800 trials
# Saved composite for original_digit_images\digit_7.png with 800 trials
# Saved composite for original_digit_images\digit_8.png with 800 trials
# Saved composite for original_digit_images\digit_9.png with 800 trials
# Saved composite for cursive_digit_images\digit_0_cursive.png with 800 trials
# Saved composite for cursive_digit_images\digit_1_cursive.png with 800 trials
# Saved composite for cursive_digit_images\digit_2_cursive.png with 800 trials
# Saved composite for cursive_digit_images\digit_3_cursive.png with 800 trials
# Saved composite for cursive_digit_images\digit_4_cursive.png with 800 trials
# Saved composite for cursive_digit_images\digit_5_cursive.png with 800 trials
# Saved composite for cursive_digit_images\digit_6_cursive.png with 800 trials
# Saved composite for cursive_digit_images\digit_7_cursive.png with 800 trials
# Saved composite for cursive_digit_images\digit_8_cursive.png with 800 trials
# Saved composite for cursive_digit_images\digit_9_cursive.png with 800 trials
# Saved composite for rotated_digit_images\digit_0_angle_22.png with 800 trials
# Saved composite for rotated_digit_images\digit_0_angle_262.png with 800 trials
# Saved composite for rotated_digit_images\digit_0_angle_287.png with 800 trials
# Saved composite for rotated_digit_images\digit_0_angle_39.png with 800 trials
# Saved composite for rotated_digit_images\digit_0_angle_70.png with 800 trials
# Saved composite for rotated_digit_images\digit_0_angle_76.png with 800 trials
# Saved composite for rotated_digit_images\digit_1_angle_280.png with 800 trials
# Saved composite for rotated_digit_images\digit_1_angle_288.png with 800 trials
# Saved composite for rotated_digit_images\digit_1_angle_30.png with 800 trials
# Saved composite for rotated_digit_images\digit_1_angle_35.png with 800 trials
# Saved composite for rotated_digit_images\digit_1_angle_62.png with 800 trials
# Saved composite for rotated_digit_images\digit_1_angle_65.png with 800 trials
# Saved composite for rotated_digit_images\digit_2_angle_25.png with 800 trials
# Saved composite for rotated_digit_images\digit_2_angle_285.png with 800 trials
# Saved composite for rotated_digit_images\digit_2_angle_289.png with 800 trials
# Saved composite for rotated_digit_images\digit_2_angle_31.png with 800 trials
# Saved composite for rotated_digit_images\digit_2_angle_72.png with 800 trials
# Saved composite for rotated_digit_images\digit_2_angle_77.png with 800 trials
# Saved composite for rotated_digit_images\digit_3_angle_26.png with 800 trials
# Saved composite for rotated_digit_images\digit_3_angle_267.png with 800 trials
# Saved composite for rotated_digit_images\digit_3_angle_27.png with 800 trials
# Saved composite for rotated_digit_images\digit_3_angle_290.png with 800 trials
# Saved composite for rotated_digit_images\digit_3_angle_75.png with 800 trials
# Saved composite for rotated_digit_images\digit_3_angle_79.png with 800 trials
# Saved composite for rotated_digit_images\digit_4_angle_23.png with 800 trials
# Saved composite for rotated_digit_images\digit_4_angle_26.png with 800 trials
# Saved composite for rotated_digit_images\digit_4_angle_264.png with 800 trials
# Saved composite for rotated_digit_images\digit_4_angle_286.png with 800 trials
# Saved composite for rotated_digit_images\digit_4_angle_72.png with 800 trials
# Saved composite for rotated_digit_images\digit_4_angle_76.png with 800 trials
# Saved composite for rotated_digit_images\digit_5_angle_270.png with 800 trials
# Saved composite for rotated_digit_images\digit_5_angle_279.png with 800 trials
# Saved composite for rotated_digit_images\digit_5_angle_38.png with 800 trials
# Saved composite for rotated_digit_images\digit_5_angle_39.png with 800 trials
# Saved composite for rotated_digit_images\digit_5_angle_66.png with 800 trials
# Saved composite for rotated_digit_images\digit_5_angle_67.png with 800 trials
# Saved composite for rotated_digit_images\digit_6_angle_26.png with 800 trials
# Saved composite for rotated_digit_images\digit_6_angle_284.png with 800 trials
# Saved composite for rotated_digit_images\digit_6_angle_285.png with 800 trials
# Saved composite for rotated_digit_images\digit_6_angle_39.png with 800 trials
# Saved composite for rotated_digit_images\digit_6_angle_63.png with 800 trials
# Saved composite for rotated_digit_images\digit_6_angle_73.png with 800 trials
# Saved composite for rotated_digit_images\digit_7_angle_20.png with 800 trials
# Saved composite for rotated_digit_images\digit_7_angle_280.png with 800 trials
# Saved composite for rotated_digit_images\digit_7_angle_38.png with 800 trials
# Saved composite for rotated_digit_images\digit_7_angle_63.png with 800 trials
# Saved composite for rotated_digit_images\digit_7_angle_74.png with 800 trials
# Saved composite for rotated_digit_images\digit_8_angle_27.png with 800 trials
# Saved composite for rotated_digit_images\digit_8_angle_286.png with 800 trials
# Saved composite for rotated_digit_images\digit_8_angle_287.png with 800 trials
# Saved composite for rotated_digit_images\digit_8_angle_31.png with 800 trials
# Saved composite for rotated_digit_images\digit_8_angle_70.png with 800 trials
# Saved composite for rotated_digit_images\digit_8_angle_77.png with 800 trials
# Saved composite for rotated_digit_images\digit_9_angle_21.png with 800 trials
# Saved composite for rotated_digit_images\digit_9_angle_276.png with 800 trials
# Saved composite for rotated_digit_images\digit_9_angle_278.png with 800 trials
# Saved composite for rotated_digit_images\digit_9_angle_35.png with 800 trials
# Saved composite for rotated_digit_images\digit_9_angle_70.png with 800 trials
# Saved composite for rotated_digit_images\digit_9_angle_71.png with 800 trials
#
# Running experiment with 2000 trials:
# Saved composite for original_digit_images\digit_0.png with 2000 trials
# Saved composite for original_digit_images\digit_1.png with 2000 trials
# Saved composite for original_digit_images\digit_2.png with 2000 trials
# Saved composite for original_digit_images\digit_3.png with 2000 trials
# Saved composite for original_digit_images\digit_4.png with 2000 trials
# Saved composite for original_digit_images\digit_5.png with 2000 trials
# Saved composite for original_digit_images\digit_6.png with 2000 trials
# Saved composite for original_digit_images\digit_7.png with 2000 trials
# Saved composite for original_digit_images\digit_8.png with 2000 trials
# Saved composite for original_digit_images\digit_9.png with 2000 trials
# Saved composite for cursive_digit_images\digit_0_cursive.png with 2000 trials
# Saved composite for cursive_digit_images\digit_1_cursive.png with 2000 trials
# Saved composite for cursive_digit_images\digit_2_cursive.png with 2000 trials
# Saved composite for cursive_digit_images\digit_3_cursive.png with 2000 trials
# Saved composite for cursive_digit_images\digit_4_cursive.png with 2000 trials
# Saved composite for cursive_digit_images\digit_5_cursive.png with 2000 trials
# Saved composite for cursive_digit_images\digit_6_cursive.png with 2000 trials
# Saved composite for cursive_digit_images\digit_7_cursive.png with 2000 trials
# Saved composite for cursive_digit_images\digit_8_cursive.png with 2000 trials
# Saved composite for cursive_digit_images\digit_9_cursive.png with 2000 trials
# Saved composite for rotated_digit_images\digit_0_angle_22.png with 2000 trials
# Saved composite for rotated_digit_images\digit_0_angle_262.png with 2000 trials
# Saved composite for rotated_digit_images\digit_0_angle_287.png with 2000 trials
# Saved composite for rotated_digit_images\digit_0_angle_39.png with 2000 trials
# Saved composite for rotated_digit_images\digit_0_angle_70.png with 2000 trials
# Saved composite for rotated_digit_images\digit_0_angle_76.png with 2000 trials
# Saved composite for rotated_digit_images\digit_1_angle_280.png with 2000 trials
# Saved composite for rotated_digit_images\digit_1_angle_288.png with 2000 trials
# Saved composite for rotated_digit_images\digit_1_angle_30.png with 2000 trials
# Saved composite for rotated_digit_images\digit_1_angle_35.png with 2000 trials
# Saved composite for rotated_digit_images\digit_1_angle_62.png with 2000 trials
# Saved composite for rotated_digit_images\digit_1_angle_65.png with 2000 trials
# Saved composite for rotated_digit_images\digit_2_angle_25.png with 2000 trials
# Saved composite for rotated_digit_images\digit_2_angle_285.png with 2000 trials
# Saved composite for rotated_digit_images\digit_2_angle_289.png with 2000 trials
# Saved composite for rotated_digit_images\digit_2_angle_31.png with 2000 trials
# Saved composite for rotated_digit_images\digit_2_angle_72.png with 2000 trials
# Saved composite for rotated_digit_images\digit_2_angle_77.png with 2000 trials
# Saved composite for rotated_digit_images\digit_3_angle_26.png with 2000 trials
# Saved composite for rotated_digit_images\digit_3_angle_267.png with 2000 trials
# Saved composite for rotated_digit_images\digit_3_angle_27.png with 2000 trials
# Saved composite for rotated_digit_images\digit_3_angle_290.png with 2000 trials
# Saved composite for rotated_digit_images\digit_3_angle_75.png with 2000 trials
# Saved composite for rotated_digit_images\digit_3_angle_79.png with 2000 trials
# Saved composite for rotated_digit_images\digit_4_angle_23.png with 2000 trials
# Saved composite for rotated_digit_images\digit_4_angle_26.png with 2000 trials
# Saved composite for rotated_digit_images\digit_4_angle_264.png with 2000 trials
# Saved composite for rotated_digit_images\digit_4_angle_286.png with 2000 trials
# Saved composite for rotated_digit_images\digit_4_angle_72.png with 2000 trials
# Saved composite for rotated_digit_images\digit_4_angle_76.png with 2000 trials
# Saved composite for rotated_digit_images\digit_5_angle_270.png with 2000 trials
# Saved composite for rotated_digit_images\digit_5_angle_279.png with 2000 trials
# Saved composite for rotated_digit_images\digit_5_angle_38.png with 2000 trials
# Saved composite for rotated_digit_images\digit_5_angle_39.png with 2000 trials
# Saved composite for rotated_digit_images\digit_5_angle_66.png with 2000 trials
# Saved composite for rotated_digit_images\digit_5_angle_67.png with 2000 trials
# Saved composite for rotated_digit_images\digit_6_angle_26.png with 2000 trials
# Saved composite for rotated_digit_images\digit_6_angle_284.png with 2000 trials
# Saved composite for rotated_digit_images\digit_6_angle_285.png with 2000 trials
# Saved composite for rotated_digit_images\digit_6_angle_39.png with 2000 trials
# Saved composite for rotated_digit_images\digit_6_angle_63.png with 2000 trials
# Saved composite for rotated_digit_images\digit_6_angle_73.png with 2000 trials
# Saved composite for rotated_digit_images\digit_7_angle_20.png with 2000 trials
# Saved composite for rotated_digit_images\digit_7_angle_280.png with 2000 trials
# Saved composite for rotated_digit_images\digit_7_angle_38.png with 2000 trials
# Saved composite for rotated_digit_images\digit_7_angle_63.png with 2000 trials
# Saved composite for rotated_digit_images\digit_7_angle_74.png with 2000 trials
# Saved composite for rotated_digit_images\digit_8_angle_27.png with 2000 trials
# Saved composite for rotated_digit_images\digit_8_angle_286.png with 2000 trials
# Saved composite for rotated_digit_images\digit_8_angle_287.png with 2000 trials
# Saved composite for rotated_digit_images\digit_8_angle_31.png with 2000 trials
# Saved composite for rotated_digit_images\digit_8_angle_70.png with 2000 trials
# Saved composite for rotated_digit_images\digit_8_angle_77.png with 2000 trials
# Saved composite for rotated_digit_images\digit_9_angle_21.png with 2000 trials
# Saved composite for rotated_digit_images\digit_9_angle_276.png with 2000 trials
# Saved composite for rotated_digit_images\digit_9_angle_278.png with 2000 trials
# Saved composite for rotated_digit_images\digit_9_angle_35.png with 2000 trials
# Saved composite for rotated_digit_images\digit_9_angle_70.png with 2000 trials
# Saved composite for rotated_digit_images\digit_9_angle_71.png with 2000 trials
#
# All composites have been generated and saved.

# %% [markdown]
# the model is woefully underperforming, perhaps we can investigate which observers is giving it a hard time.

# %%
import json
import numpy as np

class NumpyEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        return super(NumpyEncoder, self).default(obj)

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os
import re
import zipfile
import json

PIXEL_SIZE = 16
NUM_PARTICIPANTS = 100
TRIALS = [50, 75, 100, 200, 400, 800, 1600]
training_data_folder = 'training_data'

def generate_whitenoise_image():
    return np.random.randint(0, 256, PIXEL_SIZE * PIXEL_SIZE)

def calculate_similarity(vec1, vec2):
    return np.sum((vec1 - vec2) ** 2)

def run_experiment(target_image, num_trials, trial_num, observer_type, true_digit):
    all_images = []
    selections = []
    
    for trial in range(num_trials):
        stimuli = [generate_whitenoise_image() for _ in range(10)]
        similarities = [calculate_similarity(target_image, stim) for stim in stimuli]
        most_similar_index = np.argmin(similarities)
        
        selected_image = stimuli[most_similar_index]
        all_images.append(selected_image)
        selections.append({
            'trial_number': trial + 1,
            'true_digit': true_digit,
            'observer_type': observer_type,
            'selected_index': most_similar_index
        })
    
    return all_images, selections

def create_composite_image(images):
    composite = np.mean(images, axis=0)
    return ((composite - composite.min()) / (composite.max() - composite.min()) * 255).astype(np.uint8)

def load_target_image(image_path):
    img = Image.open(image_path).convert('L')  # Convert to grayscale
    img = img.resize((PIXEL_SIZE, PIXEL_SIZE), Image.LANCZOS)
    return np.array(img).flatten()

def process_and_save_images(folder_name, file_pattern, num_trials, participant_id, training_data, test_data):
    for filename in os.listdir(folder_name):
        if filename.endswith('.png'):
            match = re.match(file_pattern, filename)
            if match:
                image_path = os.path.join(folder_name, filename)
                target_image = load_target_image(image_path)
                true_digit = match.group(1)
                observer_type = 'original' if 'original' in folder_name else 'cursive' if 'cursive' in folder_name else 'rotated'
                
                experiment_results, selections = run_experiment(target_image, num_trials, participant_id, observer_type, true_digit)
                composite = create_composite_image(experiment_results)
                
                # Save selections to training data
                training_data.append(selections)
                
                # Save composite to test data
                test_data.append({
                    'participant_id': participant_id,
                    'num_trials': num_trials,
                    'true_digit': true_digit,
                    'observer_type': observer_type,
                    'composite': composite.tolist()
                })

def main():
    np.random.seed(42)  # Set random seed for reproducibility
        
    for participant in range(NUM_PARTICIPANTS):
        print(f"Processing participant {participant + 1}/{NUM_PARTICIPANTS}")
        
        training_data = []
        test_data = []
        
        for num_trials in TRIALS:
            process_and_save_images("original_digit_images", r"digit_(\d+)\.png", num_trials, participant, training_data, test_data)
            process_and_save_images("cursive_digit_images", r"digit_(\d+)_cursive\.png", num_trials, participant, training_data, test_data)
            process_and_save_images("rotated_digit_images", r"digit_(\d+)_angle_(\d+)\.png", num_trials, participant, training_data, test_data)
        
        # Save training data
        with open(os.path.join(training_data_folder, 'training_set', f'participant_{participant}.json'), 'w') as f:
            json.dump(training_data, f, cls=NumpyEncoder)
        
        # Save test data
        with open(os.path.join(training_data_folder, 'test_set', f'participant_{participant}.json'), 'w') as f:
            json.dump(test_data, f, cls=NumpyEncoder)
    
    # Create zip file
    with zipfile.ZipFile('training_data.zip', 'w') as zipf:
        for root, dirs, files in os.walk(training_data_folder):
            for file in files:
                zipf.write(os.path.join(root, file), 
                           os.path.relpath(os.path.join(root, file), 
                                           os.path.join(training_data_folder, '..')))
    
    print("All data has been generated and saved in training_data.zip")

if __name__ == "__main__":
    main()
# Out:
# Processing participant 1/100
# Processing participant 2/100
# Processing participant 3/100
# Processing participant 4/100
# Processing participant 5/100
# Processing participant 6/100
# Processing participant 7/100
# Processing participant 8/100
# Processing participant 9/100
# Processing participant 10/100
# Processing participant 11/100
# Processing participant 12/100
# Processing participant 13/100
# Processing participant 14/100
# Processing participant 15/100
# Processing participant 16/100
# Processing participant 17/100
# Processing participant 18/100
# Processing participant 19/100
# Processing participant 20/100
# Processing participant 21/100
# Processing participant 22/100
# Processing participant 23/100
# Processing participant 24/100
# Processing participant 25/100
# Processing participant 26/100
# Processing participant 27/100
# Processing participant 28/100
# Processing participant 29/100
# Processing participant 30/100
# Processing participant 31/100
# Processing participant 32/100
# Processing participant 33/100
# Processing participant 34/100
# Processing participant 35/100
# Processing participant 36/100
# Processing participant 37/100
# Processing participant 38/100
# Processing participant 39/100
# Processing participant 40/100
# Processing participant 41/100
# Processing participant 42/100
# Processing participant 43/100
# Processing participant 44/100
# Processing participant 45/100
# Processing participant 46/100
# Processing participant 47/100
# Processing participant 48/100
# Processing participant 49/100
# Processing participant 50/100
# Processing participant 51/100
# Processing participant 52/100
# Processing participant 53/100
# Processing participant 54/100
# Processing participant 55/100
# Processing participant 56/100
# Processing participant 57/100
# Processing participant 58/100
# Processing participant 59/100
# Processing participant 60/100
# Processing participant 61/100
# Processing participant 62/100
# Processing participant 63/100
# Processing participant 64/100
# Processing participant 65/100
# Processing participant 66/100
# Processing participant 67/100
# Processing participant 68/100
# Processing participant 69/100
# Processing participant 70/100
# Processing participant 71/100
# Processing participant 72/100
# Processing participant 73/100
# Processing participant 74/100
# Processing participant 75/100
# Processing participant 76/100
# Processing participant 77/100
# Processing participant 78/100
# Processing participant 79/100
# Processing participant 80/100
# Processing participant 81/100
# Processing participant 82/100
# Processing participant 83/100
# Processing participant 84/100
# Processing participant 85/100
# Processing participant 86/100
# Processing participant 87/100
# Processing participant 88/100
# Processing participant 89/100
# Processing participant 90/100
# Processing participant 91/100
# Processing participant 92/100
# Processing participant 93/100
# Processing participant 94/100
# Processing participant 95/100
# Processing participant 96/100
# Processing participant 97/100
# Processing participant 98/100
# Processing participant 99/100
# Processing participant 100/100
# All data has been generated and saved in training_data.zip

# %% [markdown]
# We made a critical mistake and forgot to actually save the training images we just saved the index :(

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os
import re
import zipfile
import json
import base64
import io

PIXEL_SIZE = 16
NUM_PARTICIPANTS = 100
TRIALS = [50, 75, 100, 200, 400, 800, 1000]
training_data_folder = 'training_data'

def generate_whitenoise_image():
    return np.random.randint(0, 256, PIXEL_SIZE * PIXEL_SIZE)

def calculate_similarity(vec1, vec2):
    return np.sum((vec1 - vec2) ** 2)

def image_to_base64(image):
    pil_img = Image.fromarray(image.reshape(PIXEL_SIZE, PIXEL_SIZE).astype(np.uint8), 'L')
    buffered = io.BytesIO()
    pil_img.save(buffered, format="PNG")
    return base64.b64encode(buffered.getvalue()).decode()

def run_experiment(target_image, num_trials, trial_num, observer_type, true_digit):
    all_images = []
    selections = []
    
    for trial in range(num_trials):
        stimuli = [generate_whitenoise_image() for _ in range(10)]
        similarities = [calculate_similarity(target_image, stim) for stim in stimuli]
        most_similar_index = np.argmin(similarities)
        
        selected_image = stimuli[most_similar_index]
        all_images.append(selected_image)
        selections.append({
            'trial_number': trial + 1,
            'true_digit': true_digit,
            'observer_type': observer_type,
            'selected_index': most_similar_index,
            'selected_image': image_to_base64(selected_image)
        })
    
    return all_images, selections

def create_composite_image(images):
    composite = np.mean(images, axis=0)
    return ((composite - composite.min()) / (composite.max() - composite.min()) * 255).astype(np.uint8)

def load_target_image(image_path):
    img = Image.open(image_path).convert('L')  # Convert to grayscale
    img = img.resize((PIXEL_SIZE, PIXEL_SIZE), Image.LANCZOS)
    return np.array(img).flatten()

def process_and_save_images(folder_name, file_pattern, num_trials, participant_id, training_data, test_data):
    for filename in os.listdir(folder_name):
        if filename.endswith('.png'):
            match = re.match(file_pattern, filename)
            if match:
                image_path = os.path.join(folder_name, filename)
                target_image = load_target_image(image_path)
                true_digit = match.group(1)
                observer_type = 'original' if 'original' in folder_name else 'cursive' if 'cursive' in folder_name else 'rotated'
                
                experiment_results, selections = run_experiment(target_image, num_trials, participant_id, observer_type, true_digit)
                composite = create_composite_image(experiment_results)
                
                # Save selections to training data
                training_data.append(selections)
                
                # Save composite to test data
                test_data.append({
                    'participant_id': participant_id,
                    'num_trials': num_trials,
                    'true_digit': true_digit,
                    'observer_type': observer_type,
                    'composite': image_to_base64(composite)
                })

class NumpyEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        return super(NumpyEncoder, self).default(obj)

def main():
    np.random.seed(42)  # Set random seed for reproducibility
    
    os.makedirs(os.path.join(training_data_folder, 'training_set'), exist_ok=True)
    os.makedirs(os.path.join(training_data_folder, 'test_set'), exist_ok=True)
    
    for participant in range(NUM_PARTICIPANTS):
        print(f"Processing participant {participant + 1}/{NUM_PARTICIPANTS}")
        
        training_data = []
        test_data = []
        
        for num_trials in TRIALS:
            process_and_save_images("original_digit_images", r"digit_(\d+)\.png", num_trials, participant, training_data, test_data)
            process_and_save_images("cursive_digit_images", r"digit_(\d+)_cursive\.png", num_trials, participant, training_data, test_data)
            process_and_save_images("rotated_digit_images", r"digit_(\d+)_angle_(\d+)\.png", num_trials, participant, training_data, test_data)
        
        # Save training data
        with open(os.path.join(training_data_folder, 'training_set', f'participant_{participant}.json'), 'w') as f:
            json.dump(training_data, f, cls=NumpyEncoder)
        
        # Save test data
        with open(os.path.join(training_data_folder, 'test_set', f'participant_{participant}.json'), 'w') as f:
            json.dump(test_data, f, cls=NumpyEncoder)
    
    # Create zip file
    with zipfile.ZipFile('training_data.zip', 'w') as zipf:
        for root, dirs, files in os.walk(training_data_folder):
            for file in files:
                zipf.write(os.path.join(root, file), 
                           os.path.relpath(os.path.join(root, file), 
                                           os.path.join(training_data_folder, '..')))
    
    print("All data has been generated and saved in training_data.zip")

if __name__ == "__main__":
    main()
# Out:
# Processing participant 1/100
# Processing participant 2/100
# Processing participant 3/100
# Processing participant 4/100
# Processing participant 5/100
# Processing participant 6/100
# Processing participant 7/100
# Processing participant 8/100
# Processing participant 9/100
# Processing participant 10/100
# Processing participant 11/100
# Processing participant 12/100
# Processing participant 13/100
# Processing participant 14/100
# Processing participant 15/100
# Processing participant 16/100
# Processing participant 17/100
# Processing participant 18/100
# Processing participant 19/100
# Processing participant 20/100
# Processing participant 21/100
# Processing participant 22/100
# Processing participant 23/100
# Processing participant 24/100
# Processing participant 25/100
# Processing participant 26/100
# Processing participant 27/100
# Processing participant 28/100
# Processing participant 29/100
# Processing participant 30/100
# Processing participant 31/100
# Processing participant 32/100
# Processing participant 33/100
# Processing participant 34/100
# Processing participant 35/100
# Processing participant 36/100
# Processing participant 37/100
# Processing participant 38/100
# Processing participant 39/100
# Processing participant 40/100
# Processing participant 41/100
# Processing participant 42/100
# Processing participant 43/100
# Processing participant 44/100
# Processing participant 45/100
# Processing participant 46/100
# Processing participant 47/100
# Processing participant 48/100
# Processing participant 49/100
# Processing participant 50/100
# Processing participant 51/100
# Processing participant 52/100
# Processing participant 53/100
# Processing participant 54/100
# Processing participant 55/100
# Processing participant 56/100
# Processing participant 57/100
# Processing participant 58/100
# Processing participant 59/100
# Processing participant 60/100
# Processing participant 61/100
# Processing participant 62/100
# Processing participant 63/100
# Processing participant 64/100
# Processing participant 65/100
# Processing participant 66/100
# Processing participant 67/100
# Processing participant 68/100
# Processing participant 69/100
# Processing participant 70/100
# Processing participant 71/100
# Processing participant 72/100
# Processing participant 73/100
# Processing participant 74/100
# Processing participant 75/100
# Processing participant 76/100
# Processing participant 77/100
# Processing participant 78/100
# Processing participant 79/100
# Processing participant 80/100
# Processing participant 81/100
# Processing participant 82/100
# Processing participant 83/100
# Processing participant 84/100
# Processing participant 85/100
# Processing participant 86/100
# Processing participant 87/100
# Processing participant 88/100
# Processing participant 89/100
# Processing participant 90/100
# Processing participant 91/100
# Processing participant 92/100
# Processing participant 93/100
# Processing participant 94/100
# Processing participant 95/100
# Processing participant 96/100
# Processing participant 97/100
# Processing participant 98/100
# Processing participant 99/100
# Processing participant 100/100
# All data has been generated and saved in training_data.zip
