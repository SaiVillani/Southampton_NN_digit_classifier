# %%
from PIL import Image, ImageDraw, ImageFont
import random
import math
import os
import numpy as np
from scipy.spatial.distance import euclidean
import zipfile

# %%
def create_digit_images():
    digits = range(10)
    digit_images = {}
    font_size = 16
    font = ImageFont.load_default()

    for digit in digits:
        while True:
            image = Image.new('L', (16, 16), 255)
            draw = ImageDraw.Draw(image)
            
            # Get the size of the digit
            bbox = draw.textbbox((0, 0), str(digit), font=font)
            digit_width = bbox[2] - bbox[0]
            digit_height = bbox[3] - bbox[1]
            
            # Calculate maximum allowed positions
            max_x = 16 - digit_width
            max_y = 16 - digit_height
            
            # Randomly place the digit in the image, ensuring full visibility
            x = random.randint(0, max_x)
            y = random.randint(0, max_y)
            
            draw.text((x, y), str(digit), fill=0, font=font)
            
            # Check if the digit is fully visible
            bbox = draw.textbbox((x, y), str(digit), font=font)
            if bbox[0] >= 0 and bbox[1] >= 0 and bbox[2] <= 16 and bbox[3] <= 16:
                break
        
        digit_images[digit] = image.resize((16, 16), Image.NEAREST)

    return digit_images

digit_images = create_digit_images()

# Display generated digit images for verification
# for digit, img in digit_images.items():
#     img.show()

# %%
# After creating digit_images
output_dir = 'original_digit_images'
os.makedirs(output_dir, exist_ok=True)
for digit, img in digit_images.items():
    img.save(os.path.join(output_dir, f'digit_{digit}.png'))

# %%
def draw_rotated_digit(digit, angle):
    # Create a larger canvas for rotation
    large_size = (48, 48)
    image = Image.new('L', large_size, 255)
    draw = ImageDraw.Draw(image)
    
    # Use a larger font size
    font_size = 16
    font = ImageFont.truetype("arial.ttf", font_size)
    
    # Get the size of the digit
    bbox = draw.textbbox((0, 0), str(digit), font=font)
    text_width = bbox[2] - bbox[0]
    text_height = bbox[3] - bbox[1]
    
    # Position the digit in the center of the large canvas
    position = ((large_size[0] - text_width) // 2, (large_size[1] - text_height) // 2)
    
    # Draw the digit in black
    draw.text(position, str(digit), fill=0, font=font)
    
    # Rotate the image
    rotated = image.rotate(angle, resample=Image.BICUBIC, expand=False)
    
    # Crop to the center 16x16 pixels
    left = (large_size[0] - 16) // 2
    top = (large_size[1] - 16) // 2
    right = left + 16
    bottom = top + 16
    final_image = rotated.crop((left, top, right, bottom))
    
    return final_image

def generate_rotated_digit_images():
    digits = range(10)
    angle_ranges = [(20, 40), (60, 80), (260, 290)]
    output_dir = 'rotated_digit_images'
    os.makedirs(output_dir, exist_ok=True)
    
    for digit in digits:
        for angle_range in angle_ranges:
            angle = random.randint(*angle_range)
            img = draw_rotated_digit(digit, angle)
            img.save(os.path.join(output_dir, f'digit_{digit}_angle_{angle}.png'))

generate_rotated_digit_images()

# %%
rotated_digit_images = generate_rotated_digit_images()

# %%
def draw_imperfect_digit(digit):
    image = Image.new('L', (16, 16), 255)  # White background
    draw = ImageDraw.Draw(image)
    font = ImageFont.load_default()
    
    # Draw the digit to create points
    temp_image = Image.new('L', (16, 16), 255)
    temp_draw = ImageDraw.Draw(temp_image)
    temp_draw.text((0, 0), str(digit), fill=0, font=font)
    
    # Collect points where the digit is drawn
    points = []
    for x in range(16):
        for y in range(16):
            if temp_image.getpixel((x, y)) == 0:  # If pixel is black (part of the digit)
                points.append((x, y))
    
    # Create imperfect points
    imperfect_points = []
    for x, y in points:
        # Add small random offsets to create imperfections
        offset_x = random.uniform(-1, 1)
        offset_y = random.uniform(-1, 1)
        imperfect_points.append((x + offset_x, y + offset_y))
    
    # Draw imperfect lines connecting the points
    for i in range(len(imperfect_points) - 1):
        start = imperfect_points[i]
        end = imperfect_points[i + 1]
        
        # Create a slightly curved line between points
        num_segments = 5
        for t in range(num_segments):
            t1 = t / num_segments
            t2 = (t + 1) / num_segments
            
            # Add some randomness to the curve
            curve_offset = random.uniform(-0.5, 0.5)
            
            x1 = start[0] * (1 - t1) + end[0] * t1 + curve_offset
            y1 = start[1] * (1 - t1) + end[1] * t1 + curve_offset
            x2 = start[0] * (1 - t2) + end[0] * t2 + curve_offset
            y2 = start[1] * (1 - t2) + end[1] * t2 + curve_offset
            
            draw.line([(x1, y1), (x2, y2)], fill=0, width=1)
    
    return image

def generate_imperfect_digit_images():
    digits = range(10)
    output_dir = 'imperfect_digit_images'
    os.makedirs(output_dir, exist_ok=True)
    
    for digit in digits:
        for i in range(5):  # Generate 5 imperfect versions of each digit
            img = draw_imperfect_digit(digit)
            img.save(os.path.join(output_dir, f'digit_{digit}_imperfect_{i}.png'))

generate_imperfect_digit_images()

# %%
def draw_cursive_digit(digit):
    # Create a larger image to draw the digit
    large_size = (64, 64)
    image = Image.new('L', large_size, 255)
    draw = ImageDraw.Draw(image)

    # Use a cursive font
    font_size = 48
    try:
        font = ImageFont.truetype("BRUSHSCI.TTF", font_size)  # Brush Script MT
    except IOError:
        font = ImageFont.truetype("ITCEDSCR.TTF", font_size)  # Edwardian Script ITC
    except IOError:
        font = ImageFont.truetype("VIVALDII.TTF", font_size)  # Vivaldi

    # Draw the digit
    draw.text((32, 32), str(digit), font=font, fill=0, anchor="mm")

    # Resize to 16x16
    image = image.resize((16, 16), Image.LANCZOS)

    # Convert to numpy array
    img_array = np.array(image)

    # Threshold to make it binary
    img_array[img_array < 128] = 0
    img_array[img_array >= 128] = 255

    return Image.fromarray(img_array)

def generate_cursive_digit_images():
    digits = range(10)
    output_dir = 'cursive_digit_images'
    os.makedirs(output_dir, exist_ok=True)
    
    for digit in digits:
        img = draw_cursive_digit(digit)
        img.save(os.path.join(output_dir, f'digit_{digit}_cursive.png'))

generate_cursive_digit_images()

# %% [markdown]
# Now we have a set of original images, cursive, and original font but rotated at funny angles, these serve as our artificial mental representations to simulate paraedolia.

# %%
import os
import numpy as np
from PIL import Image
from scipy.spatial.distance import euclidean

def create_random_stimuli(n=1000):
    return np.random.randint(0, 256, size=(n, 16, 16), dtype=np.uint8)

def vectorize_image(image):
    return np.array(image).flatten()

def select_most_similar(prototype, stimuli, n=10):
    prototype_vec = vectorize_image(prototype)
    distances = [euclidean(prototype_vec, vectorize_image(stim)) for stim in stimuli]
    return np.argsort(distances)[:n]

def process_digit(digit, stimuli, output_folder):
    # Load prototype
    prototype = Image.open(f'original_digit_images/digit_{digit}.png').convert('L')
    
    selections = []
    for i in range(10):  # 10 trials
        trial_stimuli = stimuli[i*100:(i+1)*100]
        selected = select_most_similar(prototype, trial_stimuli)
        selections.extend(selected + i*100)
    
    # Save selected stimuli
    os.makedirs(output_folder, exist_ok=True)
    for i, idx in enumerate(selections):
        Image.fromarray(stimuli[idx]).save(f'{output_folder}/digit_{digit}_selection_{i:03d}.png')

def main():
    # Create 1000 random grayscale stimuli
    stimuli = create_random_stimuli(1000)
    
    # Process each digit
    for digit in range(10):
        output_folder = f'selected_stimuli/digit_{digit}'
        process_digit(digit, stimuli, output_folder)

if __name__ == '__main__':
    main()

# %%
import os
import numpy as np
from PIL import Image
from skimage import exposure

PIXEL_SIZE = 16

def load_and_normalize_image(path):
    img = np.array(Image.open(path).convert('L')).astype(np.float32)
    return (img - np.min(img)) / (np.max(img) - np.min(img))

def create_composite_image(digit, start, end, output_folder):
    images = []
    for i in range(start, end):
        img_path = f'selected_stimuli/digit_{digit}/digit_{digit}_selection_{i:03d}.png'
        img = load_and_normalize_image(img_path)
        images.append(img)

    # Average the normalized images
    composite = np.mean(images, axis=0)

    # Apply contrast enhancement
    composite = exposure.equalize_hist(composite)

    # Convert to uint8
    composite = (composite * 255).astype(np.uint8)

    # Save the composite image
    os.makedirs(output_folder, exist_ok=True)
    Image.fromarray(composite).save(f'{output_folder}/digit_{digit}_composite_{start}_{end}.png')

def create_composites_for_digit(digit):
    output_folder = 'composite_images'
    
    create_composite_image(digit, 0, 50, output_folder)
    create_composite_image(digit, 50, 100, output_folder)
    create_composite_image(digit, 0, 100, output_folder)

def main():
    for digit in range(10):
        create_composites_for_digit(digit)

if __name__ == '__main__':
    main()

# %%
import os
import numpy as np
from PIL import Image, ImageDraw, ImageFont
import random
import zipfile

PIXEL_SIZE = 16
NUM_TRIALS = 100
DIGITS = list(range(10))
PARTICIPANT_ID = str(random.randint(0, 99)).zfill(2)

all_images = {}

def create_target_image(digit):
    image = Image.new('L', (PIXEL_SIZE, PIXEL_SIZE), 255)
    draw = ImageDraw.Draw(image)
    font = ImageFont.load_default()
    draw.text((PIXEL_SIZE // 2, PIXEL_SIZE // 2), str(digit), fill=0, font=font, anchor='mm')
    return np.array(image)

def vectorize_image(image):
    return image.flatten()

def calculate_similarity(vec1, vec2):
    return np.sum((vec1 - vec2) ** 2)

def generate_whitenoise_image():
    return np.random.randint(0, 256, size=(PIXEL_SIZE, PIXEL_SIZE), dtype=np.uint8)

def create_auto_select_trial(digit, trial_number):
    target_image = create_target_image(digit)
    target_vector = vectorize_image(target_image)
    stimuli = [generate_whitenoise_image() for _ in range(10)]

    similarities = [calculate_similarity(target_vector, vectorize_image(stim)) for stim in stimuli]
    most_similar_index = np.argmin(similarities)

    selected_image = stimuli[most_similar_index]
    image_name = f'{digit}_trial_{trial_number}_selection_participant{PARTICIPANT_ID}'
    all_images[image_name] = selected_image

    return selected_image

def create_composite_image(digit):
    relevant_images = [img for key, img in all_images.items() if key.startswith(f'{digit}_trial_')]
    sum_image = np.sum(relevant_images, axis=0).astype(np.float32)

    min_val = np.min(sum_image)
    max_val = np.max(sum_image)
    range_val = max_val - min_val if max_val != min_val else 1

    normalized = (sum_image - min_val) / range_val * 255
    return normalized.astype(np.uint8)

def download_all_images():
    with zipfile.ZipFile(f'experiment_results_participant{PARTICIPANT_ID}.zip', 'w') as zip_file:
        for name, image in all_images.items():
            img = Image.fromarray(image, mode='L')
            img.save(f'{name}.png')
            zip_file.write(f'{name}.png')
            os.remove(f'{name}.png')

        for digit in DIGITS:
            composite_image = create_composite_image(digit)
            composite_pil = Image.fromarray(composite_image, mode='L')
            composite_pil.save(f'{digit}_composite_participant{PARTICIPANT_ID}.png')
            zip_file.write(f'{digit}_composite_participant{PARTICIPANT_ID}.png')
            os.remove(f'{digit}_composite_participant{PARTICIPANT_ID}.png')

# Running the trials
for digit in DIGITS:
    for trial in range(1, NUM_TRIALS + 1):
        create_auto_select_trial(digit, trial)

# Download all images at the end
download_all_images()

# Verification step
def verify_grayscale():
    with zipfile.ZipFile(f'experiment_results_participant{PARTICIPANT_ID}.zip', 'r') as zip_file:
        for filename in zip_file.namelist():
            with zip_file.open(filename) as file:
                img = Image.open(file)
                if img.mode != 'L':
                    print(f"Warning: {filename} is not grayscale!")
                else:
                    print(f"{filename} is grayscale.")

verify_grayscale()
# Out:
# 0_trial_1_selection_participant59.png is grayscale.
# 0_trial_2_selection_participant59.png is grayscale.
# 0_trial_3_selection_participant59.png is grayscale.
# 0_trial_4_selection_participant59.png is grayscale.
# 0_trial_5_selection_participant59.png is grayscale.
# 0_trial_6_selection_participant59.png is grayscale.
# 0_trial_7_selection_participant59.png is grayscale.
# 0_trial_8_selection_participant59.png is grayscale.
# 0_trial_9_selection_participant59.png is grayscale.
# 0_trial_10_selection_participant59.png is grayscale.
# 0_trial_11_selection_participant59.png is grayscale.
# 0_trial_12_selection_participant59.png is grayscale.
# 0_trial_13_selection_participant59.png is grayscale.
# 0_trial_14_selection_participant59.png is grayscale.
# 0_trial_15_selection_participant59.png is grayscale.
# 0_trial_16_selection_participant59.png is grayscale.
# 0_trial_17_selection_participant59.png is grayscale.
# 0_trial_18_selection_participant59.png is grayscale.
# 0_trial_19_selection_participant59.png is grayscale.
# 0_trial_20_selection_participant59.png is grayscale.
# 0_trial_21_selection_participant59.png is grayscale.
# 0_trial_22_selection_participant59.png is grayscale.
# 0_trial_23_selection_participant59.png is grayscale.
# 0_trial_24_selection_participant59.png is grayscale.
# 0_trial_25_selection_participant59.png is grayscale.
# 0_trial_26_selection_participant59.png is grayscale.
# 0_trial_27_selection_participant59.png is grayscale.
# 0_trial_28_selection_participant59.png is grayscale.
# 0_trial_29_selection_participant59.png is grayscale.
# 0_trial_30_selection_participant59.png is grayscale.
# 0_trial_31_selection_participant59.png is grayscale.
# 0_trial_32_selection_participant59.png is grayscale.
# 0_trial_33_selection_participant59.png is grayscale.
# 0_trial_34_selection_participant59.png is grayscale.
# 0_trial_35_selection_participant59.png is grayscale.
# 0_trial_36_selection_participant59.png is grayscale.
# 0_trial_37_selection_participant59.png is grayscale.
# 0_trial_38_selection_participant59.png is grayscale.
# 0_trial_39_selection_participant59.png is grayscale.
# 0_trial_40_selection_participant59.png is grayscale.
# 0_trial_41_selection_participant59.png is grayscale.
# 0_trial_42_selection_participant59.png is grayscale.
# 0_trial_43_selection_participant59.png is grayscale.
# 0_trial_44_selection_participant59.png is grayscale.
# 0_trial_45_selection_participant59.png is grayscale.
# 0_trial_46_selection_participant59.png is grayscale.
# 0_trial_47_selection_participant59.png is grayscale.
# 0_trial_48_selection_participant59.png is grayscale.
# 0_trial_49_selection_participant59.png is grayscale.
# 0_trial_50_selection_participant59.png is grayscale.
# 0_trial_51_selection_participant59.png is grayscale.
# 0_trial_52_selection_participant59.png is grayscale.
# 0_trial_53_selection_participant59.png is grayscale.
# 0_trial_54_selection_participant59.png is grayscale.
# 0_trial_55_selection_participant59.png is grayscale.
# 0_trial_56_selection_participant59.png is grayscale.
# 0_trial_57_selection_participant59.png is grayscale.
# 0_trial_58_selection_participant59.png is grayscale.
# 0_trial_59_selection_participant59.png is grayscale.
# 0_trial_60_selection_participant59.png is grayscale.
# 0_trial_61_selection_participant59.png is grayscale.
# 0_trial_62_selection_participant59.png is grayscale.
# 0_trial_63_selection_participant59.png is grayscale.
# 0_trial_64_selection_participant59.png is grayscale.
# 0_trial_65_selection_participant59.png is grayscale.
# 0_trial_66_selection_participant59.png is grayscale.
# 0_trial_67_selection_participant59.png is grayscale.
# 0_trial_68_selection_participant59.png is grayscale.
# 0_trial_69_selection_participant59.png is grayscale.
# 0_trial_70_selection_participant59.png is grayscale.
# 0_trial_71_selection_participant59.png is grayscale.
# 0_trial_72_selection_participant59.png is grayscale.
# 0_trial_73_selection_participant59.png is grayscale.
# 0_trial_74_selection_participant59.png is grayscale.
# 0_trial_75_selection_participant59.png is grayscale.
# 0_trial_76_selection_participant59.png is grayscale.
# 0_trial_77_selection_participant59.png is grayscale.
# 0_trial_78_selection_participant59.png is grayscale.
# 0_trial_79_selection_participant59.png is grayscale.
# 0_trial_80_selection_participant59.png is grayscale.
# 0_trial_81_selection_participant59.png is grayscale.
# 0_trial_82_selection_participant59.png is grayscale.
# 0_trial_83_selection_participant59.png is grayscale.
# 0_trial_84_selection_participant59.png is grayscale.
# 0_trial_85_selection_participant59.png is grayscale.
# 0_trial_86_selection_participant59.png is grayscale.
# 0_trial_87_selection_participant59.png is grayscale.
# 0_trial_88_selection_participant59.png is grayscale.
# 0_trial_89_selection_participant59.png is grayscale.
# 0_trial_90_selection_participant59.png is grayscale.
# 0_trial_91_selection_participant59.png is grayscale.
# 0_trial_92_selection_participant59.png is grayscale.
# 0_trial_93_selection_participant59.png is grayscale.
# 0_trial_94_selection_participant59.png is grayscale.
# 0_trial_95_selection_participant59.png is grayscale.
# 0_trial_96_selection_participant59.png is grayscale.
# 0_trial_97_selection_participant59.png is grayscale.
# 0_trial_98_selection_participant59.png is grayscale.
# 0_trial_99_selection_participant59.png is grayscale.
# 0_trial_100_selection_participant59.png is grayscale.
# 1_trial_1_selection_participant59.png is grayscale.
# 1_trial_2_selection_participant59.png is grayscale.
# 1_trial_3_selection_participant59.png is grayscale.
# 1_trial_4_selection_participant59.png is grayscale.
# 1_trial_5_selection_participant59.png is grayscale.
# 1_trial_6_selection_participant59.png is grayscale.
# 1_trial_7_selection_participant59.png is grayscale.
# 1_trial_8_selection_participant59.png is grayscale.
# 1_trial_9_selection_participant59.png is grayscale.
# 1_trial_10_selection_participant59.png is grayscale.
# 1_trial_11_selection_participant59.png is grayscale.
# 1_trial_12_selection_participant59.png is grayscale.
# 1_trial_13_selection_participant59.png is grayscale.
# 1_trial_14_selection_participant59.png is grayscale.
# 1_trial_15_selection_participant59.png is grayscale.
# 1_trial_16_selection_participant59.png is grayscale.
# 1_trial_17_selection_participant59.png is grayscale.
# 1_trial_18_selection_participant59.png is grayscale.
# 1_trial_19_selection_participant59.png is grayscale.
# 1_trial_20_selection_participant59.png is grayscale.
# 1_trial_21_selection_participant59.png is grayscale.
# 1_trial_22_selection_participant59.png is grayscale.
# 1_trial_23_selection_participant59.png is grayscale.
# 1_trial_24_selection_participant59.png is grayscale.
# 1_trial_25_selection_participant59.png is grayscale.
# 1_trial_26_selection_participant59.png is grayscale.
# 1_trial_27_selection_participant59.png is grayscale.
# 1_trial_28_selection_participant59.png is grayscale.
# 1_trial_29_selection_participant59.png is grayscale.
# 1_trial_30_selection_participant59.png is grayscale.
# 1_trial_31_selection_participant59.png is grayscale.
# 1_trial_32_selection_participant59.png is grayscale.
# 1_trial_33_selection_participant59.png is grayscale.
# 1_trial_34_selection_participant59.png is grayscale.
# 1_trial_35_selection_participant59.png is grayscale.
# 1_trial_36_selection_participant59.png is grayscale.
# 1_trial_37_selection_participant59.png is grayscale.
# 1_trial_38_selection_participant59.png is grayscale.
# 1_trial_39_selection_participant59.png is grayscale.
# 1_trial_40_selection_participant59.png is grayscale.
# 1_trial_41_selection_participant59.png is grayscale.
# 1_trial_42_selection_participant59.png is grayscale.
# 1_trial_43_selection_participant59.png is grayscale.
# 1_trial_44_selection_participant59.png is grayscale.
# 1_trial_45_selection_participant59.png is grayscale.
# 1_trial_46_selection_participant59.png is grayscale.
# 1_trial_47_selection_participant59.png is grayscale.
# 1_trial_48_selection_participant59.png is grayscale.
# 1_trial_49_selection_participant59.png is grayscale.
# 1_trial_50_selection_participant59.png is grayscale.
# 1_trial_51_selection_participant59.png is grayscale.
# 1_trial_52_selection_participant59.png is grayscale.
# 1_trial_53_selection_participant59.png is grayscale.
# 1_trial_54_selection_participant59.png is grayscale.
# 1_trial_55_selection_participant59.png is grayscale.
# 1_trial_56_selection_participant59.png is grayscale.
# 1_trial_57_selection_participant59.png is grayscale.
# 1_trial_58_selection_participant59.png is grayscale.
# 1_trial_59_selection_participant59.png is grayscale.
# 1_trial_60_selection_participant59.png is grayscale.
# 1_trial_61_selection_participant59.png is grayscale.
# 1_trial_62_selection_participant59.png is grayscale.
# 1_trial_63_selection_participant59.png is grayscale.
# 1_trial_64_selection_participant59.png is grayscale.
# 1_trial_65_selection_participant59.png is grayscale.
# 1_trial_66_selection_participant59.png is grayscale.
# 1_trial_67_selection_participant59.png is grayscale.
# 1_trial_68_selection_participant59.png is grayscale.
# 1_trial_69_selection_participant59.png is grayscale.
# 1_trial_70_selection_participant59.png is grayscale.
# 1_trial_71_selection_participant59.png is grayscale.
# 1_trial_72_selection_participant59.png is grayscale.
# 1_trial_73_selection_participant59.png is grayscale.
# 1_trial_74_selection_participant59.png is grayscale.
# 1_trial_75_selection_participant59.png is grayscale.
# 1_trial_76_selection_participant59.png is grayscale.
# 1_trial_77_selection_participant59.png is grayscale.
# 1_trial_78_selection_participant59.png is grayscale.
# 1_trial_79_selection_participant59.png is grayscale.
# 1_trial_80_selection_participant59.png is grayscale.
# 1_trial_81_selection_participant59.png is grayscale.
# 1_trial_82_selection_participant59.png is grayscale.
# 1_trial_83_selection_participant59.png is grayscale.
# 1_trial_84_selection_participant59.png is grayscale.
# 1_trial_85_selection_participant59.png is grayscale.
# 1_trial_86_selection_participant59.png is grayscale.
# 1_trial_87_selection_participant59.png is grayscale.
# 1_trial_88_selection_participant59.png is grayscale.
# 1_trial_89_selection_participant59.png is grayscale.
# 1_trial_90_selection_participant59.png is grayscale.
# 1_trial_91_selection_participant59.png is grayscale.
# 1_trial_92_selection_participant59.png is grayscale.
# 1_trial_93_selection_participant59.png is grayscale.
# 1_trial_94_selection_participant59.png is grayscale.
# 1_trial_95_selection_participant59.png is grayscale.
# 1_trial_96_selection_participant59.png is grayscale.
# 1_trial_97_selection_participant59.png is grayscale.
# 1_trial_98_selection_participant59.png is grayscale.
# 1_trial_99_selection_participant59.png is grayscale.
# 1_trial_100_selection_participant59.png is grayscale.
# 2_trial_1_selection_participant59.png is grayscale.
# 2_trial_2_selection_participant59.png is grayscale.
# 2_trial_3_selection_participant59.png is grayscale.
# 2_trial_4_selection_participant59.png is grayscale.
# 2_trial_5_selection_participant59.png is grayscale.
# 2_trial_6_selection_participant59.png is grayscale.
# 2_trial_7_selection_participant59.png is grayscale.
# 2_trial_8_selection_participant59.png is grayscale.
# 2_trial_9_selection_participant59.png is grayscale.
# 2_trial_10_selection_participant59.png is grayscale.
# 2_trial_11_selection_participant59.png is grayscale.
# 2_trial_12_selection_participant59.png is grayscale.
# 2_trial_13_selection_participant59.png is grayscale.
# 2_trial_14_selection_participant59.png is grayscale.
# 2_trial_15_selection_participant59.png is grayscale.
# 2_trial_16_selection_participant59.png is grayscale.
# 2_trial_17_selection_participant59.png is grayscale.
# 2_trial_18_selection_participant59.png is grayscale.
# 2_trial_19_selection_participant59.png is grayscale.
# 2_trial_20_selection_participant59.png is grayscale.
# 2_trial_21_selection_participant59.png is grayscale.
# 2_trial_22_selection_participant59.png is grayscale.
# 2_trial_23_selection_participant59.png is grayscale.
# 2_trial_24_selection_participant59.png is grayscale.
# 2_trial_25_selection_participant59.png is grayscale.
# 2_trial_26_selection_participant59.png is grayscale.
# 2_trial_27_selection_participant59.png is grayscale.
# 2_trial_28_selection_participant59.png is grayscale.
# 2_trial_29_selection_participant59.png is grayscale.
# 2_trial_30_selection_participant59.png is grayscale.
# 2_trial_31_selection_participant59.png is grayscale.
# 2_trial_32_selection_participant59.png is grayscale.
# 2_trial_33_selection_participant59.png is grayscale.
# 2_trial_34_selection_participant59.png is grayscale.
# 2_trial_35_selection_participant59.png is grayscale.
# 2_trial_36_selection_participant59.png is grayscale.
# 2_trial_37_selection_participant59.png is grayscale.
# 2_trial_38_selection_participant59.png is grayscale.
# 2_trial_39_selection_participant59.png is grayscale.
# 2_trial_40_selection_participant59.png is grayscale.
# 2_trial_41_selection_participant59.png is grayscale.
# 2_trial_42_selection_participant59.png is grayscale.
# 2_trial_43_selection_participant59.png is grayscale.
# 2_trial_44_selection_participant59.png is grayscale.
# 2_trial_45_selection_participant59.png is grayscale.
# 2_trial_46_selection_participant59.png is grayscale.
# 2_trial_47_selection_participant59.png is grayscale.
# 2_trial_48_selection_participant59.png is grayscale.
# 2_trial_49_selection_participant59.png is grayscale.
# 2_trial_50_selection_participant59.png is grayscale.
# 2_trial_51_selection_participant59.png is grayscale.
# 2_trial_52_selection_participant59.png is grayscale.
# 2_trial_53_selection_participant59.png is grayscale.
# 2_trial_54_selection_participant59.png is grayscale.
# 2_trial_55_selection_participant59.png is grayscale.
# 2_trial_56_selection_participant59.png is grayscale.
# 2_trial_57_selection_participant59.png is grayscale.
# 2_trial_58_selection_participant59.png is grayscale.
# 2_trial_59_selection_participant59.png is grayscale.
# 2_trial_60_selection_participant59.png is grayscale.
# 2_trial_61_selection_participant59.png is grayscale.
# 2_trial_62_selection_participant59.png is grayscale.
# 2_trial_63_selection_participant59.png is grayscale.
# 2_trial_64_selection_participant59.png is grayscale.
# 2_trial_65_selection_participant59.png is grayscale.
# 2_trial_66_selection_participant59.png is grayscale.
# 2_trial_67_selection_participant59.png is grayscale.
# 2_trial_68_selection_participant59.png is grayscale.
# 2_trial_69_selection_participant59.png is grayscale.
# 2_trial_70_selection_participant59.png is grayscale.
# 2_trial_71_selection_participant59.png is grayscale.
# 2_trial_72_selection_participant59.png is grayscale.
# 2_trial_73_selection_participant59.png is grayscale.
# 2_trial_74_selection_participant59.png is grayscale.
# 2_trial_75_selection_participant59.png is grayscale.
# 2_trial_76_selection_participant59.png is grayscale.
# 2_trial_77_selection_participant59.png is grayscale.
# 2_trial_78_selection_participant59.png is grayscale.
# 2_trial_79_selection_participant59.png is grayscale.
# 2_trial_80_selection_participant59.png is grayscale.
# 2_trial_81_selection_participant59.png is grayscale.
# 2_trial_82_selection_participant59.png is grayscale.
# 2_trial_83_selection_participant59.png is grayscale.
# 2_trial_84_selection_participant59.png is grayscale.
# 2_trial_85_selection_participant59.png is grayscale.
# 2_trial_86_selection_participant59.png is grayscale.
# 2_trial_87_selection_participant59.png is grayscale.
# 2_trial_88_selection_participant59.png is grayscale.
# 2_trial_89_selection_participant59.png is grayscale.
# 2_trial_90_selection_participant59.png is grayscale.
# 2_trial_91_selection_participant59.png is grayscale.
# 2_trial_92_selection_participant59.png is grayscale.
# 2_trial_93_selection_participant59.png is grayscale.
# 2_trial_94_selection_participant59.png is grayscale.
# 2_trial_95_selection_participant59.png is grayscale.
# 2_trial_96_selection_participant59.png is grayscale.
# 2_trial_97_selection_participant59.png is grayscale.
# 2_trial_98_selection_participant59.png is grayscale.
# 2_trial_99_selection_participant59.png is grayscale.
# 2_trial_100_selection_participant59.png is grayscale.
# 3_trial_1_selection_participant59.png is grayscale.
# 3_trial_2_selection_participant59.png is grayscale.
# 3_trial_3_selection_participant59.png is grayscale.
# 3_trial_4_selection_participant59.png is grayscale.
# 3_trial_5_selection_participant59.png is grayscale.
# 3_trial_6_selection_participant59.png is grayscale.
# 3_trial_7_selection_participant59.png is grayscale.
# 3_trial_8_selection_participant59.png is grayscale.
# 3_trial_9_selection_participant59.png is grayscale.
# 3_trial_10_selection_participant59.png is grayscale.
# 3_trial_11_selection_participant59.png is grayscale.
# 3_trial_12_selection_participant59.png is grayscale.
# 3_trial_13_selection_participant59.png is grayscale.
# 3_trial_14_selection_participant59.png is grayscale.
# 3_trial_15_selection_participant59.png is grayscale.
# 3_trial_16_selection_participant59.png is grayscale.
# 3_trial_17_selection_participant59.png is grayscale.
# 3_trial_18_selection_participant59.png is grayscale.
# 3_trial_19_selection_participant59.png is grayscale.
# 3_trial_20_selection_participant59.png is grayscale.
# 3_trial_21_selection_participant59.png is grayscale.
# 3_trial_22_selection_participant59.png is grayscale.
# 3_trial_23_selection_participant59.png is grayscale.
# 3_trial_24_selection_participant59.png is grayscale.
# 3_trial_25_selection_participant59.png is grayscale.
# 3_trial_26_selection_participant59.png is grayscale.
# 3_trial_27_selection_participant59.png is grayscale.
# 3_trial_28_selection_participant59.png is grayscale.
# 3_trial_29_selection_participant59.png is grayscale.
# 3_trial_30_selection_participant59.png is grayscale.
# 3_trial_31_selection_participant59.png is grayscale.
# 3_trial_32_selection_participant59.png is grayscale.
# 3_trial_33_selection_participant59.png is grayscale.
# 3_trial_34_selection_participant59.png is grayscale.
# 3_trial_35_selection_participant59.png is grayscale.
# 3_trial_36_selection_participant59.png is grayscale.
# 3_trial_37_selection_participant59.png is grayscale.
# 3_trial_38_selection_participant59.png is grayscale.
# 3_trial_39_selection_participant59.png is grayscale.
# 3_trial_40_selection_participant59.png is grayscale.
# 3_trial_41_selection_participant59.png is grayscale.
# 3_trial_42_selection_participant59.png is grayscale.
# 3_trial_43_selection_participant59.png is grayscale.
# 3_trial_44_selection_participant59.png is grayscale.
# 3_trial_45_selection_participant59.png is grayscale.
# 3_trial_46_selection_participant59.png is grayscale.
# 3_trial_47_selection_participant59.png is grayscale.
# 3_trial_48_selection_participant59.png is grayscale.
# 3_trial_49_selection_participant59.png is grayscale.
# 3_trial_50_selection_participant59.png is grayscale.
# 3_trial_51_selection_participant59.png is grayscale.
# 3_trial_52_selection_participant59.png is grayscale.
# 3_trial_53_selection_participant59.png is grayscale.
# 3_trial_54_selection_participant59.png is grayscale.
# 3_trial_55_selection_participant59.png is grayscale.
# 3_trial_56_selection_participant59.png is grayscale.
# 3_trial_57_selection_participant59.png is grayscale.
# 3_trial_58_selection_participant59.png is grayscale.
# 3_trial_59_selection_participant59.png is grayscale.
# 3_trial_60_selection_participant59.png is grayscale.
# 3_trial_61_selection_participant59.png is grayscale.
# 3_trial_62_selection_participant59.png is grayscale.
# 3_trial_63_selection_participant59.png is grayscale.
# 3_trial_64_selection_participant59.png is grayscale.
# 3_trial_65_selection_participant59.png is grayscale.
# 3_trial_66_selection_participant59.png is grayscale.
# 3_trial_67_selection_participant59.png is grayscale.
# 3_trial_68_selection_participant59.png is grayscale.
# 3_trial_69_selection_participant59.png is grayscale.
# 3_trial_70_selection_participant59.png is grayscale.
# 3_trial_71_selection_participant59.png is grayscale.
# 3_trial_72_selection_participant59.png is grayscale.
# 3_trial_73_selection_participant59.png is grayscale.
# 3_trial_74_selection_participant59.png is grayscale.
# 3_trial_75_selection_participant59.png is grayscale.
# 3_trial_76_selection_participant59.png is grayscale.
# 3_trial_77_selection_participant59.png is grayscale.
# 3_trial_78_selection_participant59.png is grayscale.
# 3_trial_79_selection_participant59.png is grayscale.
# 3_trial_80_selection_participant59.png is grayscale.
# 3_trial_81_selection_participant59.png is grayscale.
# 3_trial_82_selection_participant59.png is grayscale.
# 3_trial_83_selection_participant59.png is grayscale.
# 3_trial_84_selection_participant59.png is grayscale.
# 3_trial_85_selection_participant59.png is grayscale.
# 3_trial_86_selection_participant59.png is grayscale.
# 3_trial_87_selection_participant59.png is grayscale.
# 3_trial_88_selection_participant59.png is grayscale.
# 3_trial_89_selection_participant59.png is grayscale.
# 3_trial_90_selection_participant59.png is grayscale.
# 3_trial_91_selection_participant59.png is grayscale.
# 3_trial_92_selection_participant59.png is grayscale.
# 3_trial_93_selection_participant59.png is grayscale.
# 3_trial_94_selection_participant59.png is grayscale.
# 3_trial_95_selection_participant59.png is grayscale.
# 3_trial_96_selection_participant59.png is grayscale.
# 3_trial_97_selection_participant59.png is grayscale.
# 3_trial_98_selection_participant59.png is grayscale.
# 3_trial_99_selection_participant59.png is grayscale.
# 3_trial_100_selection_participant59.png is grayscale.
# 4_trial_1_selection_participant59.png is grayscale.
# 4_trial_2_selection_participant59.png is grayscale.
# 4_trial_3_selection_participant59.png is grayscale.
# 4_trial_4_selection_participant59.png is grayscale.
# 4_trial_5_selection_participant59.png is grayscale.
# 4_trial_6_selection_participant59.png is grayscale.
# 4_trial_7_selection_participant59.png is grayscale.
# 4_trial_8_selection_participant59.png is grayscale.
# 4_trial_9_selection_participant59.png is grayscale.
# 4_trial_10_selection_participant59.png is grayscale.
# 4_trial_11_selection_participant59.png is grayscale.
# 4_trial_12_selection_participant59.png is grayscale.
# 4_trial_13_selection_participant59.png is grayscale.
# 4_trial_14_selection_participant59.png is grayscale.
# 4_trial_15_selection_participant59.png is grayscale.
# 4_trial_16_selection_participant59.png is grayscale.
# 4_trial_17_selection_participant59.png is grayscale.
# 4_trial_18_selection_participant59.png is grayscale.
# 4_trial_19_selection_participant59.png is grayscale.
# 4_trial_20_selection_participant59.png is grayscale.
# 4_trial_21_selection_participant59.png is grayscale.
# 4_trial_22_selection_participant59.png is grayscale.
# 4_trial_23_selection_participant59.png is grayscale.
# 4_trial_24_selection_participant59.png is grayscale.
# 4_trial_25_selection_participant59.png is grayscale.
# 4_trial_26_selection_participant59.png is grayscale.
# 4_trial_27_selection_participant59.png is grayscale.
# 4_trial_28_selection_participant59.png is grayscale.
# 4_trial_29_selection_participant59.png is grayscale.
# 4_trial_30_selection_participant59.png is grayscale.
# 4_trial_31_selection_participant59.png is grayscale.
# 4_trial_32_selection_participant59.png is grayscale.
# 4_trial_33_selection_participant59.png is grayscale.
# 4_trial_34_selection_participant59.png is grayscale.
# 4_trial_35_selection_participant59.png is grayscale.
# 4_trial_36_selection_participant59.png is grayscale.
# 4_trial_37_selection_participant59.png is grayscale.
# 4_trial_38_selection_participant59.png is grayscale.
# 4_trial_39_selection_participant59.png is grayscale.
# 4_trial_40_selection_participant59.png is grayscale.
# 4_trial_41_selection_participant59.png is grayscale.
# 4_trial_42_selection_participant59.png is grayscale.
# 4_trial_43_selection_participant59.png is grayscale.
# 4_trial_44_selection_participant59.png is grayscale.
# 4_trial_45_selection_participant59.png is grayscale.
# 4_trial_46_selection_participant59.png is grayscale.
# 4_trial_47_selection_participant59.png is grayscale.
# 4_trial_48_selection_participant59.png is grayscale.
# 4_trial_49_selection_participant59.png is grayscale.
# 4_trial_50_selection_participant59.png is grayscale.
# 4_trial_51_selection_participant59.png is grayscale.
# 4_trial_52_selection_participant59.png is grayscale.
# 4_trial_53_selection_participant59.png is grayscale.
# 4_trial_54_selection_participant59.png is grayscale.
# 4_trial_55_selection_participant59.png is grayscale.
# 4_trial_56_selection_participant59.png is grayscale.
# 4_trial_57_selection_participant59.png is grayscale.
# 4_trial_58_selection_participant59.png is grayscale.
# 4_trial_59_selection_participant59.png is grayscale.
# 4_trial_60_selection_participant59.png is grayscale.
# 4_trial_61_selection_participant59.png is grayscale.
# 4_trial_62_selection_participant59.png is grayscale.
# 4_trial_63_selection_participant59.png is grayscale.
# 4_trial_64_selection_participant59.png is grayscale.
# 4_trial_65_selection_participant59.png is grayscale.
# 4_trial_66_selection_participant59.png is grayscale.
# 4_trial_67_selection_participant59.png is grayscale.
# 4_trial_68_selection_participant59.png is grayscale.
# 4_trial_69_selection_participant59.png is grayscale.
# 4_trial_70_selection_participant59.png is grayscale.
# 4_trial_71_selection_participant59.png is grayscale.
# 4_trial_72_selection_participant59.png is grayscale.
# 4_trial_73_selection_participant59.png is grayscale.
# 4_trial_74_selection_participant59.png is grayscale.
# 4_trial_75_selection_participant59.png is grayscale.
# 4_trial_76_selection_participant59.png is grayscale.
# 4_trial_77_selection_participant59.png is grayscale.
# 4_trial_78_selection_participant59.png is grayscale.
# 4_trial_79_selection_participant59.png is grayscale.
# 4_trial_80_selection_participant59.png is grayscale.
# 4_trial_81_selection_participant59.png is grayscale.
# 4_trial_82_selection_participant59.png is grayscale.
# 4_trial_83_selection_participant59.png is grayscale.
# 4_trial_84_selection_participant59.png is grayscale.
# 4_trial_85_selection_participant59.png is grayscale.
# 4_trial_86_selection_participant59.png is grayscale.
# 4_trial_87_selection_participant59.png is grayscale.
# 4_trial_88_selection_participant59.png is grayscale.
# 4_trial_89_selection_participant59.png is grayscale.
# 4_trial_90_selection_participant59.png is grayscale.
# 4_trial_91_selection_participant59.png is grayscale.
# 4_trial_92_selection_participant59.png is grayscale.
# 4_trial_93_selection_participant59.png is grayscale.
# 4_trial_94_selection_participant59.png is grayscale.
# 4_trial_95_selection_participant59.png is grayscale.
# 4_trial_96_selection_participant59.png is grayscale.
# 4_trial_97_selection_participant59.png is grayscale.
# 4_trial_98_selection_participant59.png is grayscale.
# 4_trial_99_selection_participant59.png is grayscale.
# 4_trial_100_selection_participant59.png is grayscale.
# 5_trial_1_selection_participant59.png is grayscale.
# 5_trial_2_selection_participant59.png is grayscale.
# 5_trial_3_selection_participant59.png is grayscale.
# 5_trial_4_selection_participant59.png is grayscale.
# 5_trial_5_selection_participant59.png is grayscale.
# 5_trial_6_selection_participant59.png is grayscale.
# 5_trial_7_selection_participant59.png is grayscale.
# 5_trial_8_selection_participant59.png is grayscale.
# 5_trial_9_selection_participant59.png is grayscale.
# 5_trial_10_selection_participant59.png is grayscale.
# 5_trial_11_selection_participant59.png is grayscale.
# 5_trial_12_selection_participant59.png is grayscale.
# 5_trial_13_selection_participant59.png is grayscale.
# 5_trial_14_selection_participant59.png is grayscale.
# 5_trial_15_selection_participant59.png is grayscale.
# 5_trial_16_selection_participant59.png is grayscale.
# 5_trial_17_selection_participant59.png is grayscale.
# 5_trial_18_selection_participant59.png is grayscale.
# 5_trial_19_selection_participant59.png is grayscale.
# 5_trial_20_selection_participant59.png is grayscale.
# 5_trial_21_selection_participant59.png is grayscale.
# 5_trial_22_selection_participant59.png is grayscale.
# 5_trial_23_selection_participant59.png is grayscale.
# 5_trial_24_selection_participant59.png is grayscale.
# 5_trial_25_selection_participant59.png is grayscale.
# 5_trial_26_selection_participant59.png is grayscale.
# 5_trial_27_selection_participant59.png is grayscale.
# 5_trial_28_selection_participant59.png is grayscale.
# 5_trial_29_selection_participant59.png is grayscale.
# 5_trial_30_selection_participant59.png is grayscale.
# 5_trial_31_selection_participant59.png is grayscale.
# 5_trial_32_selection_participant59.png is grayscale.
# 5_trial_33_selection_participant59.png is grayscale.
# 5_trial_34_selection_participant59.png is grayscale.
# 5_trial_35_selection_participant59.png is grayscale.
# 5_trial_36_selection_participant59.png is grayscale.
# 5_trial_37_selection_participant59.png is grayscale.
# 5_trial_38_selection_participant59.png is grayscale.
# 5_trial_39_selection_participant59.png is grayscale.
# 5_trial_40_selection_participant59.png is grayscale.
# 5_trial_41_selection_participant59.png is grayscale.
# 5_trial_42_selection_participant59.png is grayscale.
# 5_trial_43_selection_participant59.png is grayscale.
# 5_trial_44_selection_participant59.png is grayscale.
# 5_trial_45_selection_participant59.png is grayscale.
# 5_trial_46_selection_participant59.png is grayscale.
# 5_trial_47_selection_participant59.png is grayscale.
# 5_trial_48_selection_participant59.png is grayscale.
# 5_trial_49_selection_participant59.png is grayscale.
# 5_trial_50_selection_participant59.png is grayscale.
# 5_trial_51_selection_participant59.png is grayscale.
# 5_trial_52_selection_participant59.png is grayscale.
# 5_trial_53_selection_participant59.png is grayscale.
# 5_trial_54_selection_participant59.png is grayscale.
# 5_trial_55_selection_participant59.png is grayscale.
# 5_trial_56_selection_participant59.png is grayscale.
# 5_trial_57_selection_participant59.png is grayscale.
# 5_trial_58_selection_participant59.png is grayscale.
# 5_trial_59_selection_participant59.png is grayscale.
# 5_trial_60_selection_participant59.png is grayscale.
# 5_trial_61_selection_participant59.png is grayscale.
# 5_trial_62_selection_participant59.png is grayscale.
# 5_trial_63_selection_participant59.png is grayscale.
# 5_trial_64_selection_participant59.png is grayscale.
# 5_trial_65_selection_participant59.png is grayscale.
# 5_trial_66_selection_participant59.png is grayscale.
# 5_trial_67_selection_participant59.png is grayscale.
# 5_trial_68_selection_participant59.png is grayscale.
# 5_trial_69_selection_participant59.png is grayscale.
# 5_trial_70_selection_participant59.png is grayscale.
# 5_trial_71_selection_participant59.png is grayscale.
# 5_trial_72_selection_participant59.png is grayscale.
# 5_trial_73_selection_participant59.png is grayscale.
# 5_trial_74_selection_participant59.png is grayscale.
# 5_trial_75_selection_participant59.png is grayscale.
# 5_trial_76_selection_participant59.png is grayscale.
# 5_trial_77_selection_participant59.png is grayscale.
# 5_trial_78_selection_participant59.png is grayscale.
# 5_trial_79_selection_participant59.png is grayscale.
# 5_trial_80_selection_participant59.png is grayscale.
# 5_trial_81_selection_participant59.png is grayscale.
# 5_trial_82_selection_participant59.png is grayscale.
# 5_trial_83_selection_participant59.png is grayscale.
# 5_trial_84_selection_participant59.png is grayscale.
# 5_trial_85_selection_participant59.png is grayscale.
# 5_trial_86_selection_participant59.png is grayscale.
# 5_trial_87_selection_participant59.png is grayscale.
# 5_trial_88_selection_participant59.png is grayscale.
# 5_trial_89_selection_participant59.png is grayscale.
# 5_trial_90_selection_participant59.png is grayscale.
# 5_trial_91_selection_participant59.png is grayscale.
# 5_trial_92_selection_participant59.png is grayscale.
# 5_trial_93_selection_participant59.png is grayscale.
# 5_trial_94_selection_participant59.png is grayscale.
# 5_trial_95_selection_participant59.png is grayscale.
# 5_trial_96_selection_participant59.png is grayscale.
# 5_trial_97_selection_participant59.png is grayscale.
# 5_trial_98_selection_participant59.png is grayscale.
# 5_trial_99_selection_participant59.png is grayscale.
# 5_trial_100_selection_participant59.png is grayscale.
# 6_trial_1_selection_participant59.png is grayscale.
# 6_trial_2_selection_participant59.png is grayscale.
# 6_trial_3_selection_participant59.png is grayscale.
# 6_trial_4_selection_participant59.png is grayscale.
# 6_trial_5_selection_participant59.png is grayscale.
# 6_trial_6_selection_participant59.png is grayscale.
# 6_trial_7_selection_participant59.png is grayscale.
# 6_trial_8_selection_participant59.png is grayscale.
# 6_trial_9_selection_participant59.png is grayscale.
# 6_trial_10_selection_participant59.png is grayscale.
# 6_trial_11_selection_participant59.png is grayscale.
# 6_trial_12_selection_participant59.png is grayscale.
# 6_trial_13_selection_participant59.png is grayscale.
# 6_trial_14_selection_participant59.png is grayscale.
# 6_trial_15_selection_participant59.png is grayscale.
# 6_trial_16_selection_participant59.png is grayscale.
# 6_trial_17_selection_participant59.png is grayscale.
# 6_trial_18_selection_participant59.png is grayscale.
# 6_trial_19_selection_participant59.png is grayscale.
# 6_trial_20_selection_participant59.png is grayscale.
# 6_trial_21_selection_participant59.png is grayscale.
# 6_trial_22_selection_participant59.png is grayscale.
# 6_trial_23_selection_participant59.png is grayscale.
# 6_trial_24_selection_participant59.png is grayscale.
# 6_trial_25_selection_participant59.png is grayscale.
# 6_trial_26_selection_participant59.png is grayscale.
# 6_trial_27_selection_participant59.png is grayscale.
# 6_trial_28_selection_participant59.png is grayscale.
# 6_trial_29_selection_participant59.png is grayscale.
# 6_trial_30_selection_participant59.png is grayscale.
# 6_trial_31_selection_participant59.png is grayscale.
# 6_trial_32_selection_participant59.png is grayscale.
# 6_trial_33_selection_participant59.png is grayscale.
# 6_trial_34_selection_participant59.png is grayscale.
# 6_trial_35_selection_participant59.png is grayscale.
# 6_trial_36_selection_participant59.png is grayscale.
# 6_trial_37_selection_participant59.png is grayscale.
# 6_trial_38_selection_participant59.png is grayscale.
# 6_trial_39_selection_participant59.png is grayscale.
# 6_trial_40_selection_participant59.png is grayscale.
# 6_trial_41_selection_participant59.png is grayscale.
# 6_trial_42_selection_participant59.png is grayscale.
# 6_trial_43_selection_participant59.png is grayscale.
# 6_trial_44_selection_participant59.png is grayscale.
# 6_trial_45_selection_participant59.png is grayscale.
# 6_trial_46_selection_participant59.png is grayscale.
# 6_trial_47_selection_participant59.png is grayscale.
# 6_trial_48_selection_participant59.png is grayscale.
# 6_trial_49_selection_participant59.png is grayscale.
# 6_trial_50_selection_participant59.png is grayscale.
# 6_trial_51_selection_participant59.png is grayscale.
# 6_trial_52_selection_participant59.png is grayscale.
# 6_trial_53_selection_participant59.png is grayscale.
# 6_trial_54_selection_participant59.png is grayscale.
# 6_trial_55_selection_participant59.png is grayscale.
# 6_trial_56_selection_participant59.png is grayscale.
# 6_trial_57_selection_participant59.png is grayscale.
# 6_trial_58_selection_participant59.png is grayscale.
# 6_trial_59_selection_participant59.png is grayscale.
# 6_trial_60_selection_participant59.png is grayscale.
# 6_trial_61_selection_participant59.png is grayscale.
# 6_trial_62_selection_participant59.png is grayscale.
# 6_trial_63_selection_participant59.png is grayscale.
# 6_trial_64_selection_participant59.png is grayscale.
# 6_trial_65_selection_participant59.png is grayscale.
# 6_trial_66_selection_participant59.png is grayscale.
# 6_trial_67_selection_participant59.png is grayscale.
# 6_trial_68_selection_participant59.png is grayscale.
# 6_trial_69_selection_participant59.png is grayscale.
# 6_trial_70_selection_participant59.png is grayscale.
# 6_trial_71_selection_participant59.png is grayscale.
# 6_trial_72_selection_participant59.png is grayscale.
# 6_trial_73_selection_participant59.png is grayscale.
# 6_trial_74_selection_participant59.png is grayscale.
# 6_trial_75_selection_participant59.png is grayscale.
# 6_trial_76_selection_participant59.png is grayscale.
# 6_trial_77_selection_participant59.png is grayscale.
# 6_trial_78_selection_participant59.png is grayscale.
# 6_trial_79_selection_participant59.png is grayscale.
# 6_trial_80_selection_participant59.png is grayscale.
# 6_trial_81_selection_participant59.png is grayscale.
# 6_trial_82_selection_participant59.png is grayscale.
# 6_trial_83_selection_participant59.png is grayscale.
# 6_trial_84_selection_participant59.png is grayscale.
# 6_trial_85_selection_participant59.png is grayscale.
# 6_trial_86_selection_participant59.png is grayscale.
# 6_trial_87_selection_participant59.png is grayscale.
# 6_trial_88_selection_participant59.png is grayscale.
# 6_trial_89_selection_participant59.png is grayscale.
# 6_trial_90_selection_participant59.png is grayscale.
# 6_trial_91_selection_participant59.png is grayscale.
# 6_trial_92_selection_participant59.png is grayscale.
# 6_trial_93_selection_participant59.png is grayscale.
# 6_trial_94_selection_participant59.png is grayscale.
# 6_trial_95_selection_participant59.png is grayscale.
# 6_trial_96_selection_participant59.png is grayscale.
# 6_trial_97_selection_participant59.png is grayscale.
# 6_trial_98_selection_participant59.png is grayscale.
# 6_trial_99_selection_participant59.png is grayscale.
# 6_trial_100_selection_participant59.png is grayscale.
# 7_trial_1_selection_participant59.png is grayscale.
# 7_trial_2_selection_participant59.png is grayscale.
# 7_trial_3_selection_participant59.png is grayscale.
# 7_trial_4_selection_participant59.png is grayscale.
# 7_trial_5_selection_participant59.png is grayscale.
# 7_trial_6_selection_participant59.png is grayscale.
# 7_trial_7_selection_participant59.png is grayscale.
# 7_trial_8_selection_participant59.png is grayscale.
# 7_trial_9_selection_participant59.png is grayscale.
# 7_trial_10_selection_participant59.png is grayscale.
# 7_trial_11_selection_participant59.png is grayscale.
# 7_trial_12_selection_participant59.png is grayscale.
# 7_trial_13_selection_participant59.png is grayscale.
# 7_trial_14_selection_participant59.png is grayscale.
# 7_trial_15_selection_participant59.png is grayscale.
# 7_trial_16_selection_participant59.png is grayscale.
# 7_trial_17_selection_participant59.png is grayscale.
# 7_trial_18_selection_participant59.png is grayscale.
# 7_trial_19_selection_participant59.png is grayscale.
# 7_trial_20_selection_participant59.png is grayscale.
# 7_trial_21_selection_participant59.png is grayscale.
# 7_trial_22_selection_participant59.png is grayscale.
# 7_trial_23_selection_participant59.png is grayscale.
# 7_trial_24_selection_participant59.png is grayscale.
# 7_trial_25_selection_participant59.png is grayscale.
# 7_trial_26_selection_participant59.png is grayscale.
# 7_trial_27_selection_participant59.png is grayscale.
# 7_trial_28_selection_participant59.png is grayscale.
# 7_trial_29_selection_participant59.png is grayscale.
# 7_trial_30_selection_participant59.png is grayscale.
# 7_trial_31_selection_participant59.png is grayscale.
# 7_trial_32_selection_participant59.png is grayscale.
# 7_trial_33_selection_participant59.png is grayscale.
# 7_trial_34_selection_participant59.png is grayscale.
# 7_trial_35_selection_participant59.png is grayscale.
# 7_trial_36_selection_participant59.png is grayscale.
# 7_trial_37_selection_participant59.png is grayscale.
# 7_trial_38_selection_participant59.png is grayscale.
# 7_trial_39_selection_participant59.png is grayscale.
# 7_trial_40_selection_participant59.png is grayscale.
# 7_trial_41_selection_participant59.png is grayscale.
# 7_trial_42_selection_participant59.png is grayscale.
# 7_trial_43_selection_participant59.png is grayscale.
# 7_trial_44_selection_participant59.png is grayscale.
# 7_trial_45_selection_participant59.png is grayscale.
# 7_trial_46_selection_participant59.png is grayscale.
# 7_trial_47_selection_participant59.png is grayscale.
# 7_trial_48_selection_participant59.png is grayscale.
# 7_trial_49_selection_participant59.png is grayscale.
# 7_trial_50_selection_participant59.png is grayscale.
# 7_trial_51_selection_participant59.png is grayscale.
# 7_trial_52_selection_participant59.png is grayscale.
# 7_trial_53_selection_participant59.png is grayscale.
# 7_trial_54_selection_participant59.png is grayscale.
# 7_trial_55_selection_participant59.png is grayscale.
# 7_trial_56_selection_participant59.png is grayscale.
# 7_trial_57_selection_participant59.png is grayscale.
# 7_trial_58_selection_participant59.png is grayscale.
# 7_trial_59_selection_participant59.png is grayscale.
# 7_trial_60_selection_participant59.png is grayscale.
# 7_trial_61_selection_participant59.png is grayscale.
# 7_trial_62_selection_participant59.png is grayscale.
# 7_trial_63_selection_participant59.png is grayscale.
# 7_trial_64_selection_participant59.png is grayscale.
# 7_trial_65_selection_participant59.png is grayscale.
# 7_trial_66_selection_participant59.png is grayscale.
# 7_trial_67_selection_participant59.png is grayscale.
# 7_trial_68_selection_participant59.png is grayscale.
# 7_trial_69_selection_participant59.png is grayscale.
# 7_trial_70_selection_participant59.png is grayscale.
# 7_trial_71_selection_participant59.png is grayscale.
# 7_trial_72_selection_participant59.png is grayscale.
# 7_trial_73_selection_participant59.png is grayscale.
# 7_trial_74_selection_participant59.png is grayscale.
# 7_trial_75_selection_participant59.png is grayscale.
# 7_trial_76_selection_participant59.png is grayscale.
# 7_trial_77_selection_participant59.png is grayscale.
# 7_trial_78_selection_participant59.png is grayscale.
# 7_trial_79_selection_participant59.png is grayscale.
# 7_trial_80_selection_participant59.png is grayscale.
# 7_trial_81_selection_participant59.png is grayscale.
# 7_trial_82_selection_participant59.png is grayscale.
# 7_trial_83_selection_participant59.png is grayscale.
# 7_trial_84_selection_participant59.png is grayscale.
# 7_trial_85_selection_participant59.png is grayscale.
# 7_trial_86_selection_participant59.png is grayscale.
# 7_trial_87_selection_participant59.png is grayscale.
# 7_trial_88_selection_participant59.png is grayscale.
# 7_trial_89_selection_participant59.png is grayscale.
# 7_trial_90_selection_participant59.png is grayscale.
# 7_trial_91_selection_participant59.png is grayscale.
# 7_trial_92_selection_participant59.png is grayscale.
# 7_trial_93_selection_participant59.png is grayscale.
# 7_trial_94_selection_participant59.png is grayscale.
# 7_trial_95_selection_participant59.png is grayscale.
# 7_trial_96_selection_participant59.png is grayscale.
# 7_trial_97_selection_participant59.png is grayscale.
# 7_trial_98_selection_participant59.png is grayscale.
# 7_trial_99_selection_participant59.png is grayscale.
# 7_trial_100_selection_participant59.png is grayscale.
# 8_trial_1_selection_participant59.png is grayscale.
# 8_trial_2_selection_participant59.png is grayscale.
# 8_trial_3_selection_participant59.png is grayscale.
# 8_trial_4_selection_participant59.png is grayscale.
# 8_trial_5_selection_participant59.png is grayscale.
# 8_trial_6_selection_participant59.png is grayscale.
# 8_trial_7_selection_participant59.png is grayscale.
# 8_trial_8_selection_participant59.png is grayscale.
# 8_trial_9_selection_participant59.png is grayscale.
# 8_trial_10_selection_participant59.png is grayscale.
# 8_trial_11_selection_participant59.png is grayscale.
# 8_trial_12_selection_participant59.png is grayscale.
# 8_trial_13_selection_participant59.png is grayscale.
# 8_trial_14_selection_participant59.png is grayscale.
# 8_trial_15_selection_participant59.png is grayscale.
# 8_trial_16_selection_participant59.png is grayscale.
# 8_trial_17_selection_participant59.png is grayscale.
# 8_trial_18_selection_participant59.png is grayscale.
# 8_trial_19_selection_participant59.png is grayscale.
# 8_trial_20_selection_participant59.png is grayscale.
# 8_trial_21_selection_participant59.png is grayscale.
# 8_trial_22_selection_participant59.png is grayscale.
# 8_trial_23_selection_participant59.png is grayscale.
# 8_trial_24_selection_participant59.png is grayscale.
# 8_trial_25_selection_participant59.png is grayscale.
# 8_trial_26_selection_participant59.png is grayscale.
# 8_trial_27_selection_participant59.png is grayscale.
# 8_trial_28_selection_participant59.png is grayscale.
# 8_trial_29_selection_participant59.png is grayscale.
# 8_trial_30_selection_participant59.png is grayscale.
# 8_trial_31_selection_participant59.png is grayscale.
# 8_trial_32_selection_participant59.png is grayscale.
# 8_trial_33_selection_participant59.png is grayscale.
# 8_trial_34_selection_participant59.png is grayscale.
# 8_trial_35_selection_participant59.png is grayscale.
# 8_trial_36_selection_participant59.png is grayscale.
# 8_trial_37_selection_participant59.png is grayscale.
# 8_trial_38_selection_participant59.png is grayscale.
# 8_trial_39_selection_participant59.png is grayscale.
# 8_trial_40_selection_participant59.png is grayscale.
# 8_trial_41_selection_participant59.png is grayscale.
# 8_trial_42_selection_participant59.png is grayscale.
# 8_trial_43_selection_participant59.png is grayscale.
# 8_trial_44_selection_participant59.png is grayscale.
# 8_trial_45_selection_participant59.png is grayscale.
# 8_trial_46_selection_participant59.png is grayscale.
# 8_trial_47_selection_participant59.png is grayscale.
# 8_trial_48_selection_participant59.png is grayscale.
# 8_trial_49_selection_participant59.png is grayscale.
# 8_trial_50_selection_participant59.png is grayscale.
# 8_trial_51_selection_participant59.png is grayscale.
# 8_trial_52_selection_participant59.png is grayscale.
# 8_trial_53_selection_participant59.png is grayscale.
# 8_trial_54_selection_participant59.png is grayscale.
# 8_trial_55_selection_participant59.png is grayscale.
# 8_trial_56_selection_participant59.png is grayscale.
# 8_trial_57_selection_participant59.png is grayscale.
# 8_trial_58_selection_participant59.png is grayscale.
# 8_trial_59_selection_participant59.png is grayscale.
# 8_trial_60_selection_participant59.png is grayscale.
# 8_trial_61_selection_participant59.png is grayscale.
# 8_trial_62_selection_participant59.png is grayscale.
# 8_trial_63_selection_participant59.png is grayscale.
# 8_trial_64_selection_participant59.png is grayscale.
# 8_trial_65_selection_participant59.png is grayscale.
# 8_trial_66_selection_participant59.png is grayscale.
# 8_trial_67_selection_participant59.png is grayscale.
# 8_trial_68_selection_participant59.png is grayscale.
# 8_trial_69_selection_participant59.png is grayscale.
# 8_trial_70_selection_participant59.png is grayscale.
# 8_trial_71_selection_participant59.png is grayscale.
# 8_trial_72_selection_participant59.png is grayscale.
# 8_trial_73_selection_participant59.png is grayscale.
# 8_trial_74_selection_participant59.png is grayscale.
# 8_trial_75_selection_participant59.png is grayscale.
# 8_trial_76_selection_participant59.png is grayscale.
# 8_trial_77_selection_participant59.png is grayscale.
# 8_trial_78_selection_participant59.png is grayscale.
# 8_trial_79_selection_participant59.png is grayscale.
# 8_trial_80_selection_participant59.png is grayscale.
# 8_trial_81_selection_participant59.png is grayscale.
# 8_trial_82_selection_participant59.png is grayscale.
# 8_trial_83_selection_participant59.png is grayscale.
# 8_trial_84_selection_participant59.png is grayscale.
# 8_trial_85_selection_participant59.png is grayscale.
# 8_trial_86_selection_participant59.png is grayscale.
# 8_trial_87_selection_participant59.png is grayscale.
# 8_trial_88_selection_participant59.png is grayscale.
# 8_trial_89_selection_participant59.png is grayscale.
# 8_trial_90_selection_participant59.png is grayscale.
# 8_trial_91_selection_participant59.png is grayscale.
# 8_trial_92_selection_participant59.png is grayscale.
# 8_trial_93_selection_participant59.png is grayscale.
# 8_trial_94_selection_participant59.png is grayscale.
# 8_trial_95_selection_participant59.png is grayscale.
# 8_trial_96_selection_participant59.png is grayscale.
# 8_trial_97_selection_participant59.png is grayscale.
# 8_trial_98_selection_participant59.png is grayscale.
# 8_trial_99_selection_participant59.png is grayscale.
# 8_trial_100_selection_participant59.png is grayscale.
# 9_trial_1_selection_participant59.png is grayscale.
# 9_trial_2_selection_participant59.png is grayscale.
# 9_trial_3_selection_participant59.png is grayscale.
# 9_trial_4_selection_participant59.png is grayscale.
# 9_trial_5_selection_participant59.png is grayscale.
# 9_trial_6_selection_participant59.png is grayscale.
# 9_trial_7_selection_participant59.png is grayscale.
# 9_trial_8_selection_participant59.png is grayscale.
# 9_trial_9_selection_participant59.png is grayscale.
# 9_trial_10_selection_participant59.png is grayscale.
# 9_trial_11_selection_participant59.png is grayscale.
# 9_trial_12_selection_participant59.png is grayscale.
# 9_trial_13_selection_participant59.png is grayscale.
# 9_trial_14_selection_participant59.png is grayscale.
# 9_trial_15_selection_participant59.png is grayscale.
# 9_trial_16_selection_participant59.png is grayscale.
# 9_trial_17_selection_participant59.png is grayscale.
# 9_trial_18_selection_participant59.png is grayscale.
# 9_trial_19_selection_participant59.png is grayscale.
# 9_trial_20_selection_participant59.png is grayscale.
# 9_trial_21_selection_participant59.png is grayscale.
# 9_trial_22_selection_participant59.png is grayscale.
# 9_trial_23_selection_participant59.png is grayscale.
# 9_trial_24_selection_participant59.png is grayscale.
# 9_trial_25_selection_participant59.png is grayscale.
# 9_trial_26_selection_participant59.png is grayscale.
# 9_trial_27_selection_participant59.png is grayscale.
# 9_trial_28_selection_participant59.png is grayscale.
# 9_trial_29_selection_participant59.png is grayscale.
# 9_trial_30_selection_participant59.png is grayscale.
# 9_trial_31_selection_participant59.png is grayscale.
# 9_trial_32_selection_participant59.png is grayscale.
# 9_trial_33_selection_participant59.png is grayscale.
# 9_trial_34_selection_participant59.png is grayscale.
# 9_trial_35_selection_participant59.png is grayscale.
# 9_trial_36_selection_participant59.png is grayscale.
# 9_trial_37_selection_participant59.png is grayscale.
# 9_trial_38_selection_participant59.png is grayscale.
# 9_trial_39_selection_participant59.png is grayscale.
# 9_trial_40_selection_participant59.png is grayscale.
# 9_trial_41_selection_participant59.png is grayscale.
# 9_trial_42_selection_participant59.png is grayscale.
# 9_trial_43_selection_participant59.png is grayscale.
# 9_trial_44_selection_participant59.png is grayscale.
# 9_trial_45_selection_participant59.png is grayscale.
# 9_trial_46_selection_participant59.png is grayscale.
# 9_trial_47_selection_participant59.png is grayscale.
# 9_trial_48_selection_participant59.png is grayscale.
# 9_trial_49_selection_participant59.png is grayscale.
# 9_trial_50_selection_participant59.png is grayscale.
# 9_trial_51_selection_participant59.png is grayscale.
# 9_trial_52_selection_participant59.png is grayscale.
# 9_trial_53_selection_participant59.png is grayscale.
# 9_trial_54_selection_participant59.png is grayscale.
# 9_trial_55_selection_participant59.png is grayscale.
# 9_trial_56_selection_participant59.png is grayscale.
# 9_trial_57_selection_participant59.png is grayscale.
# 9_trial_58_selection_participant59.png is grayscale.
# 9_trial_59_selection_participant59.png is grayscale.
# 9_trial_60_selection_participant59.png is grayscale.
# 9_trial_61_selection_participant59.png is grayscale.
# 9_trial_62_selection_participant59.png is grayscale.
# 9_trial_63_selection_participant59.png is grayscale.
# 9_trial_64_selection_participant59.png is grayscale.
# 9_trial_65_selection_participant59.png is grayscale.
# 9_trial_66_selection_participant59.png is grayscale.
# 9_trial_67_selection_participant59.png is grayscale.
# 9_trial_68_selection_participant59.png is grayscale.
# 9_trial_69_selection_participant59.png is grayscale.
# 9_trial_70_selection_participant59.png is grayscale.
# 9_trial_71_selection_participant59.png is grayscale.
# 9_trial_72_selection_participant59.png is grayscale.
# 9_trial_73_selection_participant59.png is grayscale.
# 9_trial_74_selection_participant59.png is grayscale.
# 9_trial_75_selection_participant59.png is grayscale.
# 9_trial_76_selection_participant59.png is grayscale.
# 9_trial_77_selection_participant59.png is grayscale.
# 9_trial_78_selection_participant59.png is grayscale.
# 9_trial_79_selection_participant59.png is grayscale.
# 9_trial_80_selection_participant59.png is grayscale.
# 9_trial_81_selection_participant59.png is grayscale.
# 9_trial_82_selection_participant59.png is grayscale.
# 9_trial_83_selection_participant59.png is grayscale.
# 9_trial_84_selection_participant59.png is grayscale.
# 9_trial_85_selection_participant59.png is grayscale.
# 9_trial_86_selection_participant59.png is grayscale.
# 9_trial_87_selection_participant59.png is grayscale.
# 9_trial_88_selection_participant59.png is grayscale.
# 9_trial_89_selection_participant59.png is grayscale.
# 9_trial_90_selection_participant59.png is grayscale.
# 9_trial_91_selection_participant59.png is grayscale.
# 9_trial_92_selection_participant59.png is grayscale.
# 9_trial_93_selection_participant59.png is grayscale.
# 9_trial_94_selection_participant59.png is grayscale.
# 9_trial_95_selection_participant59.png is grayscale.
# 9_trial_96_selection_participant59.png is grayscale.
# 9_trial_97_selection_participant59.png is grayscale.
# 9_trial_98_selection_participant59.png is grayscale.
# 9_trial_99_selection_participant59.png is grayscale.
# 9_trial_100_selection_participant59.png is grayscale.
# 0_composite_participant59.png is grayscale.
# 1_composite_participant59.png is grayscale.
# 2_composite_participant59.png is grayscale.
# 3_composite_participant59.png is grayscale.
# 4_composite_participant59.png is grayscale.
# 5_composite_participant59.png is grayscale.
# 6_composite_participant59.png is grayscale.
# 7_composite_participant59.png is grayscale.
# 8_composite_participant59.png is grayscale.
# 9_composite_participant59.png is grayscale.

# %%
import matplotlib.pyplot as plt

def visualize_composites():
    fig, axes = plt.subplots(2, 5, figsize=(15, 6))
    fig.suptitle("Composite Images for Each Digit", fontsize=16)
    
    for digit, ax in zip(DIGITS, axes.flatten()):
        composite_image = create_composite_image(digit)
        ax.imshow(composite_image, cmap='gray')
        ax.set_title(f'Digit {digit}')
        ax.axis('off')
    
    plt.tight_layout()
    plt.show()

# Call the function to visualize composites
visualize_composites()

# %%
def verify_saved_images():
    for digit in DIGITS:
        path = f'selected_stimuli/digit_{digit}'
        if os.path.exists(path):
            files = os.listdir(path)
            print(f"Digit {digit}: {len(files)} images saved")
        else:
            print(f"No directory found for digit {digit}")

# %%
import os
import numpy as np
from PIL import Image, ImageDraw, ImageFont
import random
import zipfile
import matplotlib.pyplot as plt

PIXEL_SIZE = 16
NUM_TRIALS = 100
DIGITS = list(range(10))
PARTICIPANT_ID = str(random.randint(0, 99)).zfill(2)

all_images = {}

def create_target_image(digit):
    image = Image.new('L', (PIXEL_SIZE, PIXEL_SIZE), 255)
    draw = ImageDraw.Draw(image)
    font = ImageFont.load_default()
    draw.text((PIXEL_SIZE // 2, PIXEL_SIZE // 2), str(digit), fill=0, font=font, anchor='mm')
    return np.array(image)

def vectorize_image(image):
    return image.flatten()

def calculate_similarity(vec1, vec2):
    return np.sum((vec1 - vec2) ** 2)

def generate_whitenoise_image():
    return np.random.randint(0, 256, size=(PIXEL_SIZE, PIXEL_SIZE), dtype=np.uint8)

def create_auto_select_trial(digit, trial_number):
    target_image = create_target_image(digit)
    target_vector = vectorize_image(target_image)
    stimuli = [generate_whitenoise_image() for _ in range(10)]

    similarities = [calculate_similarity(target_vector, vectorize_image(stim)) for stim in stimuli]
    most_similar_index = np.argmin(similarities)

    selected_image = stimuli[most_similar_index]
    image_name = f'digit_{digit}_selection_{trial_number:03d}'
    
    # Save the selected image
    os.makedirs(f'selected_stimuli/digit_{digit}', exist_ok=True)
    Image.fromarray(selected_image).save(f'selected_stimuli/digit_{digit}/{image_name}.png')

    all_images[image_name] = selected_image

def create_composite_image(digit):
    relevant_images = [img for key, img in all_images.items() if key.startswith(f'{digit}_trial_')]
    sum_image = np.sum(relevant_images, axis=0).astype(np.float32)

    # Normalize the composite image
    min_val = np.min(sum_image)
    max_val = np.max(sum_image)
    range_val = max_val - min_val if max_val != min_val else 1

    normalized = (sum_image - min_val) / range_val * 255
    return normalized.astype(np.uint8)

def download_all_images():
    with zipfile.ZipFile(f'experiment_results_participant{PARTICIPANT_ID}.zip', 'w') as zip_file:
        for name, image in all_images.items():
            img = Image.fromarray(image, mode='L')
            img.save(f'{name}.png')
            zip_file.write(f'{name}.png')
            os.remove(f'{name}.png')

        for digit in DIGITS:
            composite_image = create_composite_image(digit)
            composite_pil = Image.fromarray(composite_image, mode='L')
            composite_pil.save(f'{digit}_composite_participant{PARTICIPANT_ID}.png')
            zip_file.write(f'{digit}_composite_participant{PARTICIPANT_ID}.png')
            os.remove(f'{digit}_composite_participant{PARTICIPANT_ID}.png')

def visualize_composites():
    fig, axes = plt.subplots(2, 5, figsize=(15, 6))
    fig.suptitle("Composite Images for Each Digit", fontsize=16)

    for digit, ax in zip(DIGITS, axes.flatten()):
        composite_image = create_composite_image(digit)
        ax.imshow(composite_image, cmap='gray')
        ax.set_title(f'Digit {digit}')
        ax.axis('off')

    plt.tight_layout()
    plt.show()

# Running the trials
for digit in DIGITS:
    for trial in range(1, NUM_TRIALS + 1):
        create_auto_select_trial(digit, trial)

# Download all images at the end
download_all_images()

# Call this function after running all trials
verify_saved_images()

# Visualize composites
visualize_composites()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[36], line 94
#      91         create_auto_select_trial(digit, trial)
#      93 # Download all images at the end
# ---> 94 download_all_images()
#      96 # Call this function after running all trials
#      97 verify_saved_images()
#
# Cell In[36], line 70, in download_all_images()
#      68 for digit in DIGITS:
#      69     composite_image = create_composite_image(digit)
# ---> 70     composite_pil = Image.fromarray(composite_image, mode='L')
#      71     composite_pil.save(f'{digit}_composite_participant{PARTICIPANT_ID}.png')
#      72     zip_file.write(f'{digit}_composite_participant{PARTICIPANT_ID}.png')
#
# File c:\Users\Sai\Desktop\NN_digit_classifier\Southampton_NN_digit_classifier\env\lib\site-packages\PIL\Image.py:3294, in fromarray(obj, mode)
#    3291     msg = f"Too many dimensions: {ndim} > {ndmax}."
#    3292     raise ValueError(msg)
# -> 3294 size = 1 if ndim == 1 else shape[1], shape[0]
#    3295 if strides is not None:
#    3296     if hasattr(obj, "tobytes"):
#
# IndexError: tuple index out of range

# %%
import os
import numpy as np
from PIL import Image, ImageDraw, ImageFont
import random
import zipfile
import matplotlib.pyplot as plt

PIXEL_SIZE = 16
NUM_TRIALS = 100
DIGITS = list(range(10))
PARTICIPANT_ID = str(random.randint(0, 99)).zfill(2)

all_images = {}

def create_target_image(digit):
    image = Image.new('L', (PIXEL_SIZE, PIXEL_SIZE), 255)
    draw = ImageDraw.Draw(image)
    font = ImageFont.load_default()
    draw.text((PIXEL_SIZE // 2, PIXEL_SIZE // 2), str(digit), fill=0, font=font, anchor='mm')
    return np.array(image)

def vectorize_image(image):
    return image.flatten()

def calculate_similarity(vec1, vec2):
    return np.sum((vec1 - vec2) ** 2)

def generate_whitenoise_image():
    return np.random.randint(0, 256, size=(PIXEL_SIZE, PIXEL_SIZE), dtype=np.uint8)

def create_auto_select_trial(digit, trial_number):
    target_image = create_target_image(digit)
    target_vector = vectorize_image(target_image)
    stimuli = [generate_whitenoise_image() for _ in range(10)]

    similarities = [calculate_similarity(target_vector, vectorize_image(stim)) for stim in stimuli]
    most_similar_index = np.argmin(similarities)

    selected_image = stimuli[most_similar_index]
    image_name = f'digit_{digit}_selection_{trial_number:03d}'
    
    # Save the selected image
    os.makedirs(f'selected_stimuli/digit_{digit}', exist_ok=True)
    Image.fromarray(selected_image).save(f'selected_stimuli/digit_{digit}/{image_name}.png')

    all_images[image_name] = selected_image

def create_composite_image(digit):
    relevant_images = [img for key, img in all_images.items() if key.startswith(f'digit_{digit}_')]
    
    if not relevant_images:
        print(f"No images found for digit {digit}.")
        return np.zeros((PIXEL_SIZE, PIXEL_SIZE), dtype=np.uint8)

    sum_image = np.sum(relevant_images, axis=0).astype(np.float32)

    min_val = np.min(sum_image)
    max_val = np.max(sum_image)
    range_val = max_val - min_val if max_val != min_val else 1

    normalized = (sum_image - min_val) / range_val * 255
    return normalized.astype(np.uint8)

def download_all_images():
    with zipfile.ZipFile(f'experiment_results_participant{PARTICIPANT_ID}.zip', 'w') as zip_file:
        for name, image in all_images.items():
            img = Image.fromarray(image, mode='L')
            img.save(f'{name}.png')
            zip_file.write(f'{name}.png')
            os.remove(f'{name}.png')

        for digit in DIGITS:
            composite_image = create_composite_image(digit)
            composite_pil = Image.fromarray(composite_image, mode='L')
            composite_pil.save(f'{digit}_composite_participant{PARTICIPANT_ID}.png')
            zip_file.write(f'{digit}_composite_participant{PARTICIPANT_ID}.png')
            os.remove(f'{digit}_composite_participant{PARTICIPANT_ID}.png')

# Running the trials
for digit in DIGITS:
    for trial in range(1, NUM_TRIALS + 1):
        create_auto_select_trial(digit, trial)

# Download all images at the end
download_all_images()

# Visualize composites
for digit in DIGITS:
    composite_image = create_composite_image(digit)
    plt.figure(figsize=(2, 2))
    plt.imshow(composite_image, cmap='gray')
    plt.title(f'Composite Image for Digit {digit}')
    plt.axis('off')
    plt.show()
